# %%
from __future__ import print_function
import keras
from keras.utils import np_utils

from keras.datasets import cifar10
from keras.preprocessing.image import ImageDataGenerator
from keras.models import Sequential
from keras.preprocessing import image
from keras.applications.imagenet_utils import preprocess_input
from keras.layers import Dense, Dropout, Activation, Flatten
from keras.layers import Conv2D, MaxPooling2D, BatchNormalization
from keras import optimizers
from sklearn.model_selection import train_test_split
import numpy as np
import re
import os
from keras.layers.core import Lambda
from keras import backend as K
from keras import regularizers
import time
start_time = 0
def sorted_alphanumeric(data):
    convert = lambda text: int(text) if text.isdigit() else text.lower()
    alphanum_key = lambda key: [convert(c) for c in re.split('([0-9]+)', key)]
    return sorted(data, key=alphanum_key)



class CNN2_CRC:
    def __init__(self,train=True):
        self.model = self.build_model()
        if train:
            self.model = self.train(self.model)
        else:
            self.model.load_weights('CNN2_CRC.h5')


    def build_model(self):
        # Build the network of vgg for 10 classes with massive dropout and weight decay

        model = Sequential()
        weight_decay = 0.0005

        model.add(Conv2D(64, (3, 3), padding='same', input_shape=(32, 32, 3),
                         kernel_regularizer=regularizers.l2(weight_decay)))
        model.add(Activation('relu'))
        model.add(BatchNormalization())
        model.add(Dropout(0.3))
        model.add(Conv2D(64, (3, 3), padding='same', kernel_regularizer=regularizers.l2(weight_decay),kernel_initializer='glorot_normal'))
        model.add(Activation('relu'))
        model.add(BatchNormalization())
        model.add(MaxPooling2D(pool_size=(2, 2)))
        model.add(Conv2D(128, (3, 3), padding='same', kernel_regularizer=regularizers.l2(weight_decay),kernel_initializer='glorot_normal'))
        model.add(Activation('relu'))
        model.add(BatchNormalization())
        model.add(Dropout(0.4))
        model.add(Conv2D(128, (3, 3), padding='same', kernel_regularizer=regularizers.l2(weight_decay),kernel_initializer='glorot_normal'))
        model.add(Activation('relu'))
        model.add(BatchNormalization())
        model.add(MaxPooling2D(pool_size=(2, 2)))
        model.add(Conv2D(256, (3, 3), padding='same', kernel_regularizer=regularizers.l2(weight_decay),kernel_initializer='glorot_normal'))
        model.add(Activation('relu'))
        model.add(BatchNormalization())
        model.add(Dropout(0.4))
        model.add(Conv2D(256, (3, 3), padding='same', kernel_regularizer=regularizers.l2(weight_decay),kernel_initializer='glorot_normal'))
        model.add(Activation('relu'))
        model.add(BatchNormalization())
        model.add(Dropout(0.4))
        model.add(Conv2D(256, (3, 3), padding='same', kernel_regularizer=regularizers.l2(weight_decay),kernel_initializer='glorot_normal'))
        model.add(Activation('relu'))
        model.add(BatchNormalization())
        model.add(MaxPooling2D(pool_size=(2, 2)))
        model.add(Conv2D(512, (3, 3), padding='same', kernel_regularizer=regularizers.l2(weight_decay),kernel_initializer='glorot_normal'))
        model.add(Activation('relu'))
        model.add(BatchNormalization())
        model.add(Dropout(0.4))
        model.add(Conv2D(512, (3, 3), padding='same', kernel_regularizer=regularizers.l2(weight_decay),kernel_initializer='glorot_normal'))
        model.add(Activation('relu'))
        model.add(BatchNormalization())
        model.add(Dropout(0.4))
        model.add(Conv2D(512, (3, 3), padding='same', kernel_regularizer=regularizers.l2(weight_decay),kernel_initializer='glorot_normal'))
        model.add(Activation('relu'))
        model.add(BatchNormalization())
        model.add(MaxPooling2D(pool_size=(2, 2)))
        model.add(Conv2D(512, (3, 3), padding='same', kernel_regularizer=regularizers.l2(weight_decay),kernel_initializer='glorot_normal'))
        model.add(Activation('relu'))
        model.add(BatchNormalization())
        model.add(Dropout(0.4))
        model.add(Conv2D(512, (3, 3), padding='same', kernel_regularizer=regularizers.l2(weight_decay),kernel_initializer='glorot_normal'))
        model.add(Activation('relu'))
        model.add(BatchNormalization())
        model.add(Dropout(0.4))
        model.add(Conv2D(512, (3, 3), padding='same', kernel_regularizer=regularizers.l2(weight_decay),kernel_initializer='glorot_normal'))
        model.add(Activation('relu'))
        model.add(BatchNormalization())
        model.add(MaxPooling2D(pool_size=(2, 2)))
        model.add(Dropout(0.5))
        model.add(Flatten())
        model.add(Dense(4))
        model.add(Activation('softmax'))
        model.summary()
        return model

    #Test what if no normalization is used
    def normalize(self,X_train,X_test):
        #this function normalize inputs for zero mean and unit variance
        # it is used when training a model.
        mean = np.mean(X_train,axis=(0,1,2,3))
        std = np.std(X_train, axis=(0, 1, 2, 3))
        X_train = (X_train-mean)/(std+1e-7)
        X_test = (X_test-mean)/(std+1e-7)
        return X_train, X_test

    #Test what if no normalization is used
    def normalize_production(self,x):
        #this function is used to normalize instances in production according to saved training set statistics
        # Input: X - a training set
        # Output X - a normalized training set according to normalization constants.

        #these values produced during first training and are general for the standard cifar10 training set normalization
        mean = 120.707
        std = 64.15
        return (x-mean)/(std+1e-7)

    def predict(self,x,normalize=True,batch_size=50):
        if normalize:
            x = self.normalize_production(x)
        return self.model.predict(x,batch_size)

    def train(self,model):

        #training parameters
        batch_size = 128
        #maxepoches = 250
        maxepoches = 2
        learning_rate = 0.1
        lr_decay = 1e-6
        lr_drop = 20
        # The data, shuffled and split between train and test sets:
        PATH = "./Assignment2-Data/patch_images/"
        data_path = PATH
        data_dir_list = sorted_alphanumeric(os.listdir(data_path))
        print(data_dir_list)

        img_data_list = []

        for dataset in sorted_alphanumeric(data_dir_list):
            print(dataset)
            img_path = data_path + '/' + dataset
            img = image.load_img(img_path, target_size=(32,32))
            x = image.img_to_array(img)
            x = np.expand_dims(x, axis=0)
            x = preprocess_input(x)
            #     x = x/255
            print('Input image shape:', x.shape)
            img_data_list.append(x)
            

        img_data = np.array(img_data_list)
        print(img_data.shape)
        img_data = np.rollaxis(img_data, 1, 0)
        print(img_data.shape)
        img_data = img_data[0]
        print(img_data.shape)
        num_of_samples = img_data.shape[0]
        print("sample", num_of_samples)
        labels = np.ones((num_of_samples,), dtype='int64')
        labels[0:7722] = 0
        labels[7722:13434] = 1
        labels[13434:20225] = 2
        labels[20225:] = 3
        names = ['epithelial', 'fibroblast', 'inflammatory', 'others']
        num_classes = 4
        Y = np_utils.to_categorical(labels, num_classes)

        x_train, x_test, y_train, y_test = train_test_split(img_data, Y, test_size=0.2, random_state=2)
        x_train = x_train.astype('float32')
        x_test = x_test.astype('float32')
        #Normalize the sample
        x_train, x_test = self.normalize(x_train, x_test)


        def lr_scheduler(epoch):
            return learning_rate * (0.5 ** (epoch // lr_drop))
        
        #Callbacks to be used while training the model
        reduce_lr = keras.callbacks.LearningRateScheduler(lr_scheduler)
        es = keras.callbacks.EarlyStopping(monitor='val_loss', mode='min', verbose=1)

        #data augmentation
        datagen = ImageDataGenerator(
            # rotate images in random order (degrees, 0 to 180)
            rotation_range=15,  
            # shift images horizontally in random order
            width_shift_range=0.1,  
            # shift images vertically in random order
            height_shift_range=0.1,  
            horizontal_flip=True,  
            vertical_flip=True)  
        # (std, mean, and principal components if ZCA whitening is applied).
        datagen.fit(x_train)



        #optimization details
        #try out better performance metrics
        sgd = optimizers.SGD(lr=learning_rate, decay=lr_decay, momentum=0.9, nesterov=True)
        model.compile(loss='categorical_crossentropy', optimizer=sgd,metrics=['accuracy'])
        

        import time
        start_time = time.time()
        history = model.fit_generator(datagen.flow(x_train, y_train,
                                         batch_size=batch_size),
                            steps_per_epoch=x_train.shape[0] // batch_size,
                            epochs=maxepoches,
                            validation_data=(x_test, y_test),callbacks=[reduce_lr, es],verbose=2)

        print('Max Test accuracy:', max(history.history['val_accuracy']))
        scores = model.evaluate(x_test, y_test, verbose=1)
        print('Test loss:', scores[0])
        print('Test accuracy:', scores[1])
        import matplotlib.pyplot as plt
        # # visualizing losses and accuracy
        print(history.history.keys())
        # # summarize history for accuracy
        plt.plot(history.history['accuracy'])
        plt.plot(history.history['val_accuracy'])
        plt.title('model accuracy')
        plt.ylabel('Accuracy')
        plt.xlabel('epoch')
        plt.legend(['train', 'test'], loc='upper left')
        plt.show()
        # summarize history for loss
        plt.plot(history.history['loss'])
        plt.plot(history.history['val_loss'])
        plt.title('model loss')
        plt.ylabel('loss')
        plt.xlabel('epoch')
        plt.legend(['train', 'test'], loc='upper left')
        plt.show()                 

        return model

if __name__ == '__main__':

    PATH = "./Assignment2-Data/patch_images/"
    data_path = PATH
    data_dir_list = sorted_alphanumeric(os.listdir(data_path))
    print(data_dir_list)

    img_data_list = []


    for dataset in sorted_alphanumeric(data_dir_list):
        print(dataset)
        img_path = data_path + '/' + dataset
        img = image.load_img(img_path, target_size=(32, 32))
        x = image.img_to_array(img)
        x = np.expand_dims(x, axis=0)
        x = preprocess_input(x)
        #     x = x/255
        print('Input image shape:', x.shape)
        img_data_list.append(x)



    img_data = np.array(img_data_list)
    # img_data = img_data.astype('float32')
    print(img_data.shape)
    img_data = np.rollaxis(img_data, 1, 0)
    print(img_data.shape)
    img_data = img_data[0]
    print(img_data.shape)
    num_of_samples = img_data.shape[0]
    print("sample", num_of_samples)
    labels = np.ones((num_of_samples,), dtype='int64')
    labels[0:7722] = 0
    labels[7722:13434] = 1
    labels[13434:20225] = 2
    labels[20225:] = 3
    names = ['epithelial', 'fibroblast', 'inflammatory', 'others']
    num_classes = 4
    Y = np_utils.to_categorical(labels, num_classes)
    print("x shape:",img_data.shape)
    print("y shape",Y.shape)

    x_train, x_test, y_train, y_test = train_test_split(img_data, Y, test_size=0.2, random_state=2)
    x_train = x_train.astype('float32')
    x_test = x_test.astype('float32')

    y_train = keras.utils.to_categorical(y_train, 4)
    y_test = keras.utils.to_categorical(y_test, 4)

    model = CNN2_CRC()


    print("---  Training time in seconds ---%s " % (time.time() - start_time))
    predicted_x = model.predict(x_test)
    residuals = np.argmax(predicted_x,1)!=np.argmax(y_test,1)

#     loss = sum(residuals)/len(residuals)
# print("the validation 0/1 loss is: ",loss)
# Out:
# ['1.png', '2.png', '3.png', '4.png', '5.png', '6.png', '7.png', '8.png', '9.png', '10.png', '11.png', '14.png', '15.png', '16.png', '17.png', '18.png', '19.png', '20.png', '21.png', '22.png', '23.png', '24.png', '25.png', '26.png', '27.png', '28.png', '29.png', '30.png', '31.png', '32.png', '33.png', '34.png', '35.png', '36.png', '37.png', '38.png', '39.png', '40.png', '41.png', '42.png', '43.png', '44.png', '45.png', '46.png', '47.png', '48.png', '49.png', '50.png', '51.png', '52.png', '53.png', '54.png', '55.png', '56.png', '57.png', '58.png', '59.png', '60.png', '61.png', '62.png', '63.png', '64.png', '65.png', '66.png', '67.png', '68.png', '69.png', '70.png', '71.png', '72.png', '73.png', '74.png', '75.png', '76.png', '77.png', '78.png', '79.png', '80.png', '82.png', '83.png', '84.png', '85.png', '86.png', '87.png', '88.png', '89.png', '90.png', '91.png', '92.png', '93.png', '94.png', '95.png', '96.png', '97.png', '98.png', '99.png', '100.png', '101.png', '102.png', '103.png', '104.png', '105.png', '106.png', '107.png', '108.png', '109.png', '110.png', '111.png', '112.png', '113.png', '114.png', '115.png', '116.png', '117.png', '118.png', '119.png', '120.png', '121.png', '122.png', '123.png', '124.png', '125.png', '126.png', '127.png', '128.png', '129.png', '130.png', '131.png', '132.png', '133.png', '134.png', '135.png', '136.png', '137.png', '138.png', '140.png', '141.png', '142.png', '143.png', '144.png', '145.png', '146.png', '147.png', '148.png', '149.png', '150.png', '152.png', '153.png', '154.png', '155.png', '156.png', '157.png', '158.png', '161.png', '162.png', '163.png', '164.png', '165.png', '166.png', '167.png', '168.png', '169.png', '171.png', '172.png', '173.png', '174.png', '175.png', '176.png', '177.png', '178.png', '179.png', '180.png', '181.png', '182.png', '183.png', '184.png', '185.png', '186.png', '187.png', '188.png', '189.png', '190.png', '191.png', '192.png', '193.png', '194.png', '195.png', '196.png', '197.png', '198.png', '199.png', '200.png', '201.png', '202.png', '203.png', '204.png', '205.png', '206.png', '207.png', '208.png', '209.png', '210.png', '211.png', '212.png', '213.png', '214.png', '215.png', '216.png', '217.png', '218.png', '220.png', '221.png', '222.png', '223.png', '224.png', '225.png', '226.png', '227.png', '228.png', '229.png', '230.png', '231.png', '232.png', '233.png', '234.png', '235.png', '236.png', '237.png', '238.png', '239.png', '240.png', '241.png', '242.png', '243.png', '244.png', '245.png', '246.png', '247.png', '248.png', '249.png', '250.png', '251.png', '252.png', '253.png', '254.png', '255.png', '256.png', '257.png', '258.png', '259.png', '260.png', '261.png', '262.png', '263.png', '264.png', '265.png', '269.png', '270.png', '271.png', '273.png', '274.png', '275.png', '276.png', '277.png', '278.png', '279.png', '280.png', '281.png', '282.png', '283.png', '284.png', '285.png', '286.png', '287.png', '288.png', '289.png', '290.png', '291.png', '292.png', '293.png', '294.png', '295.png', '296.png', '297.png', '298.png', '299.png', '300.png', '301.png', '302.png', '303.png', '304.png', '305.png', '306.png', '307.png', '308.png', '309.png', '310.png', '311.png', '313.png', '314.png', '315.png', '316.png', '317.png', '318.png', '319.png', '320.png', '321.png', '322.png', '323.png', '324.png', '325.png', '326.png', '327.png', '328.png', '329.png', '331.png', '333.png', '334.png', '335.png', '336.png', '337.png', '338.png', '339.png', '341.png', '342.png', '343.png', '344.png', '345.png', '346.png', '347.png', '348.png', '350.png', '351.png', '352.png', '353.png', '354.png', '355.png', '356.png', '357.png', '358.png', '360.png', '362.png', '363.png', '364.png', '365.png', '366.png', '367.png', '368.png', '369.png', '370.png', '371.png', '373.png', '374.png', '375.png', '376.png', '377.png', '378.png', '379.png', '380.png', '381.png', '382.png', '383.png', '384.png', '385.png', '386.png', '387.png', '388.png', '389.png', '390.png', '391.png', '394.png', '395.png', '396.png', ' ...
# 1.png
# Input image shape: (1, 32, 32, 3)
# 2.png
# Input image shape: (1, 32, 32, 3)
# 3.png
# Input image shape: (1, 32, 32, 3)
# 4.png
# Input image shape: (1, 32, 32, 3)
# 5.png
# Input image shape: (1, 32, 32, 3)
# 6.png
# Input image shape: (1, 32, 32, 3)
# 7.png
# Input image shape: (1, 32, 32, 3)
# 8.png
# Input image shape: (1, 32, 32, 3)
# 9.png
# Input image shape: (1, 32, 32, 3)
# 10.png
# Input image shape: (1, 32, 32, 3)
# 11.png
# Input image shape: (1, 32, 32, 3)
# 14.png
# Input image shape: (1, 32, 32, 3)
# 15.png
# Input image shape: (1, 32, 32, 3)
# 16.png
# Input image shape: (1, 32, 32, 3)
# 17.png
# Input image shape: (1, 32, 32, 3)
# 18.png
# Input image shape: (1, 32, 32, 3)
# 19.png
# Input image shape: (1, 32, 32, 3)
# 20.png
# Input image shape: (1, 32, 32, 3)
# 21.png
# Input image shape: (1, 32, 32, 3)
# 22.png
# Input image shape: (1, 32, 32, 3)
# 23.png
# Input image shape: (1, 32, 32, 3)
# 24.png
# Input image shape: (1, 32, 32, 3)
# 25.png
# Input image shape: (1, 32, 32, 3)
# 26.png
# Input image shape: (1, 32, 32, 3)
# 27.png
# Input image shape: (1, 32, 32, 3)
# 28.png
# Input image shape: (1, 32, 32, 3)
# 29.png
# Input image shape: (1, 32, 32, 3)
# 30.png
# Input image shape: (1, 32, 32, 3)
# 31.png
# Input image shape: (1, 32, 32, 3)
# 32.png
# Input image shape: (1, 32, 32, 3)
# 33.png
# Input image shape: (1, 32, 32, 3)
# 34.png
# Input image shape: (1, 32, 32, 3)
# 35.png
# Input image shape: (1, 32, 32, 3)
# 36.png
# Input image shape: (1, 32, 32, 3)
# 37.png
# Input image shape: (1, 32, 32, 3)
# 38.png
# Input image shape: (1, 32, 32, 3)
# 39.png
# Input image shape: (1, 32, 32, 3)
# 40.png
# Input image shape: (1, 32, 32, 3)
# 41.png
# Input image shape: (1, 32, 32, 3)
# 42.png
# Input image shape: (1, 32, 32, 3)
# 43.png
# Input image shape: (1, 32, 32, 3)
# 44.png
# Input image shape: (1, 32, 32, 3)
# 45.png
# Input image shape: (1, 32, 32, 3)
# 46.png
# Input image shape: (1, 32, 32, 3)
# 47.png
# Input image shape: (1, 32, 32, 3)
# 48.png
# Input image shape: (1, 32, 32, 3)
# 49.png
# Input image shape: (1, 32, 32, 3)
# 50.png
# Input image shape: (1, 32, 32, 3)
# 51.png
# Input image shape: (1, 32, 32, 3)
# 52.png
# Input image shape: (1, 32, 32, 3)
# 53.png
# Input image shape: (1, 32, 32, 3)
# 54.png
# Input image shape: (1, 32, 32, 3)
# 55.png
# Input image shape: (1, 32, 32, 3)
# 56.png
# Input image shape: (1, 32, 32, 3)
# 57.png
# Input image shape: (1, 32, 32, 3)
# 58.png
# Input image shape: (1, 32, 32, 3)
# 59.png
# Input image shape: (1, 32, 32, 3)
# 60.png
# Input image shape: (1, 32, 32, 3)
# 61.png
# Input image shape: (1, 32, 32, 3)
# 62.png
# Input image shape: (1, 32, 32, 3)
# 63.png
# Input image shape: (1, 32, 32, 3)
# 64.png
# Input image shape: (1, 32, 32, 3)
# 65.png
# Input image shape: (1, 32, 32, 3)
# 66.png
# Input image shape: (1, 32, 32, 3)
# 67.png
# Input image shape: (1, 32, 32, 3)
# 68.png
# Input image shape: (1, 32, 32, 3)
# 69.png
# Input image shape: (1, 32, 32, 3)
# 70.png
# Input image shape: (1, 32, 32, 3)
# 71.png
# Input image shape: (1, 32, 32, 3)
# 72.png
# Input image shape: (1, 32, 32, 3)
# 73.png
# Input image shape: (1, 32, 32, 3)
# 74.png
# Input image shape: (1, 32, 32, 3)
# 75.png
# Input image shape: (1, 32, 32, 3)
# 76.png
# Input image shape: (1, 32, 32, 3)
# 77.png
# Input image shape: (1, 32, 32, 3)
# 78.png
# Input image shape: (1, 32, 32, 3)
# 79.png
# Input image shape: (1, 32, 32, 3)
# 80.png
# Input image shape: (1, 32, 32, 3)
# 82.png
# Input image shape: (1, 32, 32, 3)
# 83.png
# Input image shape: (1, 32, 32, 3)
# 84.png
# Input image shape: (1, 32, 32, 3)
# 85.png
# Input image shape: (1, 32, 32, 3)
# 86.png
# Input image shape: (1, 32, 32, 3)
# 87.png
# Input image shape: (1, 32, 32, 3)
# 88.png
# Input image shape: (1, 32, 32, 3)
# 89.png
# Input image shape: (1, 32, 32, 3)
# 90.png
# Input image shape: (1, 32, 32, 3)
# 91.png
# Input image shape: (1, 32, 32, 3)
# 92.png
# Input image shape: (1, 32, 32, 3)
# 93.png
# Input image shape: (1, 32, 32, 3)
# 94.png
# Input image shape: (1, 32, 32, 3)
# 95.png
# Input image shape: (1, 32, 32, 3)
# 96.png
# Input image shape: (1, 32, 32, 3)
# 97.png
# Input image shape: (1, 32, 32, 3)
# 98.png
# Input image shape: (1, 32, 32, 3)
# 99.png
# Input image shape: (1, 32, 32, 3)
# 100.png
# Input image shape: (1, 32, 32, 3)
# 101.png
# Input image shape: (1, 32, 32, 3)
# 102.png
# Input image shape: (1, 32, 32, 3)
# 103.png
# Input image shape: (1, 32, 32, 3)
# 104.png
# Input image shape: (1, 32, 32, 3)
# 105.png
# Input image shape: (1, 32, 32, 3)
# 106.png
# Input image shape: (1, 32, 32, 3)
# 107.png
# Input image shape: (1, 32, 32, 3)
# 108.png
# Input image shape: (1, 32, 32, 3)
# 109.png
# Input image shape: (1, 32, 32, 3)
# 110.png
# Input image shape: (1, 32, 32, 3)
# 111.png
# Input image shape: (1, 32, 32, 3)
# 112.png
# Input image shape: (1, 32, 32, 3)
# 113.png
# Input image shape: (1, 32, 32, 3)
# 114.png
# Input image shape: (1, 32, 32, 3)
# 115.png
# Input image shape: (1, 32, 32, 3)
# 116.png
# Input image shape: (1, 32, 32, 3)
# 117.png
# Input image shape: (1, 32, 32, 3)
# 118.png
# Input image shape: (1, 32, 32, 3)
# 119.png
# Input image shape: (1, 32, 32, 3)
# 120.png
# Input image shape: (1, 32, 32, 3)
# 121.png
# Input image shape: (1, 32, 32, 3)
# 122.png
# Input image shape: (1, 32, 32, 3)
# 123.png
# Input image shape: (1, 32, 32, 3)
# 124.png
# Input image shape: (1, 32, 32, 3)
# 125.png
# Input image shape: (1, 32, 32, 3)
# 126.png
# Input image shape: (1, 32, 32, 3)
# 127.png
# Input image shape: (1, 32, 32, 3)
# 128.png
# Input image shape: (1, 32, 32, 3)
# 129.png
# Input image shape: (1, 32, 32, 3)
# 130.png
# Input image shape: (1, 32, 32, 3)
# 131.png
# Input image shape: (1, 32, 32, 3)
# 132.png
# Input image shape: (1, 32, 32, 3)
# 133.png
# Input image shape: (1, 32, 32, 3)
# 134.png
# Input image shape: (1, 32, 32, 3)
# 135.png
# Input image shape: (1, 32, 32, 3)
# 136.png
# Input image shape: (1, 32, 32, 3)
# 137.png
# Input image shape: (1, 32, 32, 3)
# 138.png
# Input image shape: (1, 32, 32, 3)
# 140.png
# Input image shape: (1, 32, 32, 3)
# 141.png
# Input image shape: (1, 32, 32, 3)
# 142.png
# Input image shape: (1, 32, 32, 3)
# 143.png
# Input image shape: (1, 32, 32, 3)
# 144.png
# Input image shape: (1, 32, 32, 3)
# 145.png
# Input image shape: (1, 32, 32, 3)
# 146.png
# Input image shape: (1, 32, 32, 3)
# 147.png
# Input image shape: (1, 32, 32, 3)
# 148.png
# Input image shape: (1, 32, 32, 3)
# 149.png
# Input image shape: (1, 32, 32, 3)
# 150.png
# Input image shape: (1, 32, 32, 3)
# 152.png
# Input image shape: (1, 32, 32, 3)
# 153.png
# Input image shape: (1, 32, 32, 3)
# 154.png
# Input image shape: (1, 32, 32, 3)
# 155.png
# Input image shape: (1, 32, 32, 3)
# 156.png
# Input image shape: (1, 32, 32, 3)
# 157.png
# Input image shape: (1, 32, 32, 3)
# 158.png
# Input image shape: (1, 32, 32, 3)
# 161.png
# Input image shape: (1, 32, 32, 3)
# 162.png
# Input image shape: (1, 32, 32, 3)
# 163.png
# Input image shape: (1, 32, 32, 3)
# 164.png
# Input image shape: (1, 32, 32, 3)
# 165.png
# Input image shape: (1, 32, 32, 3)
# 166.png
# Input image shape: (1, 32, 32, 3)
# 167.png
# Input image shape: (1, 32, 32, 3)
# 168.png
# Input image shape: (1, 32, 32, 3)
# 169.png
# Input image shape: (1, 32, 32, 3)
# 171.png
# Input image shape: (1, 32, 32, 3)
# 172.png
# Input image shape: (1, 32, 32, 3)
# 173.png
# Input image shape: (1, 32, 32, 3)
# 174.png
# Input image shape: (1, 32, 32, 3)
# 175.png
# Input image shape: (1, 32, 32, 3)
# 176.png
# Input image shape: (1, 32, 32, 3)
# 177.png
# Input image shape: (1, 32, 32, 3)
# 178.png
# Input image shape: (1, 32, 32, 3)
# 179.png
# Input image shape: (1, 32, 32, 3)
# 180.png
# Input image shape: (1, 32, 32, 3)
# 181.png
# Input image shape: (1, 32, 32, 3)
# 182.png
# Input image shape: (1, 32, 32, 3)
# 183.png
# Input image shape: (1, 32, 32, 3)
# 184.png
# Input image shape: (1, 32, 32, 3)
# 185.png
# Input image shape: (1, 32, 32, 3)
# 186.png
# Input image shape: (1, 32, 32, 3)
# 187.png
# Input image shape: (1, 32, 32, 3)
# 188.png
# Input image shape: (1, 32, 32, 3)
# 189.png
# Input image shape: (1, 32, 32, 3)
# 190.png
# Input image shape: (1, 32, 32, 3)
# 191.png
# Input image shape: (1, 32, 32, 3)
# 192.png
# Input image shape: (1, 32, 32, 3)
# 193.png
# Input image shape: (1, 32, 32, 3)
# 194.png
# Input image shape: (1, 32, 32, 3)
# 195.png
# Input image shape: (1, 32, 32, 3)
# 196.png
# Input image shape: (1, 32, 32, 3)
# 197.png
# Input image shape: (1, 32, 32, 3)
# 198.png
# Input image shape: (1, 32, 32, 3)
# 199.png
# Input image shape: (1, 32, 32, 3)
# 200.png
# Input image shape: (1, 32, 32, 3)
# 201.png
# Input image shape: (1, 32, 32, 3)
# 202.png
# Input image shape: (1, 32, 32, 3)
# 203.png
# Input image shape: (1, 32, 32, 3)
# 204.png
# Input image shape: (1, 32, 32, 3)
# 205.png
# Input image shape: (1, 32, 32, 3)
# 206.png
# Input image shape: (1, 32, 32, 3)
# 207.png
# Input image shape: (1, 32, 32, 3)
# 208.png
# Input image shape: (1, 32, 32, 3)
# 209.png
# Input image shape: (1, 32, 32, 3)
# 210.png
# Input image shape: (1, 32, 32, 3)
# 211.png
# Input image shape: (1, 32, 32, 3)
# 212.png
# Input image shape: (1, 32, 32, 3)
# 213.png
# Input image shape: (1, 32, 32, 3)
# 214.png
# Input image shape: (1, 32, 32, 3)
# 215.png
# Input image shape: (1, 32, 32, 3)
# 216.png
# Input image shape: (1, 32, 32, 3)
# 217.png
# Input image shape: (1, 32, 32, 3)
# 218.png
# Input image shape: (1, 32, 32, 3)
# 220.png
# Input image shape: (1, 32, 32, 3)
# 221.png
# Input image shape: (1, 32, 32, 3)
# 222.png
# Input image shape: (1, 32, 32, 3)
# 223.png
# Input image shape: (1, 32, 32, 3)
# 224.png
# Input image shape: (1, 32, 32, 3)
# 225.png
# Input image shape: (1, 32, 32, 3)
# 226.png
# Input image shape: (1, 32, 32, 3)
# 227.png
# Input image shape: (1, 32, 32, 3)
# 228.png
# Input image shape: (1, 32, 32, 3)
# 229.png
# Input image shape: (1, 32, 32, 3)
# 230.png
# Input image shape: (1, 32, 32, 3)
# 231.png
# Input image shape: (1, 32, 32, 3)
# 232.png
# Input image shape: (1, 32, 32, 3)
# 233.png
# Input image shape: (1, 32, 32, 3)
# 234.png
# Input image shape: (1, 32, 32, 3)
# 235.png
# Input image shape: (1, 32, 32, 3)
# 236.png
# Input image shape: (1, 32, 32, 3)
# 237.png
# Input image shape: (1, 32, 32, 3)
# 238.png
# Input image shape: (1, 32, 32, 3)
# 239.png
# Input image shape: (1, 32, 32, 3)
# 240.png
# Input image shape: (1, 32, 32, 3)
# 241.png
# Input image shape: (1, 32, 32, 3)
# 242.png
# Input image shape: (1, 32, 32, 3)
# 243.png
# Input image shape: (1, 32, 32, 3)
# 244.png
# Input image shape: (1, 32, 32, 3)
# 245.png
# Input image shape: (1, 32, 32, 3)
# 246.png
# Input image shape: (1, 32, 32, 3)
# 247.png
# Input image shape: (1, 32, 32, 3)
# 248.png
# Input image shape: (1, 32, 32, 3)
# 249.png
# Input image shape: (1, 32, 32, 3)
# 250.png
# Input image shape: (1, 32, 32, 3)
# 251.png
# Input image shape: (1, 32, 32, 3)
# 252.png
# Input image shape: (1, 32, 32, 3)
# 253.png
# Input image shape: (1, 32, 32, 3)
# 254.png
# Input image shape: (1, 32, 32, 3)
# 255.png
# Input image shape: (1, 32, 32, 3)
# 256.png
# Input image shape: (1, 32, 32, 3)
# 257.png
# Input image shape: (1, 32, 32, 3)
# 258.png
# Input image shape: (1, 32, 32, 3)
# 259.png
# Input image shape: (1, 32, 32, 3)
# 260.png
# Input image shape: (1, 32, 32, 3)
# 261.png
# Input image shape: (1, 32, 32, 3)
# 262.png
# Input image shape: (1, 32, 32, 3)
# 263.png
# Input image shape: (1, 32, 32, 3)
# 264.png
# Input image shape: (1, 32, 32, 3)
# 265.png
# Input image shape: (1, 32, 32, 3)
# 269.png
# Input image shape: (1, 32, 32, 3)
# 270.png
# Input image shape: (1, 32, 32, 3)
# 271.png
# Input image shape: (1, 32, 32, 3)
# 273.png
# Input image shape: (1, 32, 32, 3)
# 274.png
# Input image shape: (1, 32, 32, 3)
# 275.png
# Input image shape: (1, 32, 32, 3)
# 276.png
# Input image shape: (1, 32, 32, 3)
# 277.png
# Input image shape: (1, 32, 32, 3)
# 278.png
# Input image shape: (1, 32, 32, 3)
# 279.png
# Input image shape: (1, 32, 32, 3)
# 280.png
# Input image shape: (1, 32, 32, 3)
# 281.png
# Input image shape: (1, 32, 32, 3)
# 282.png
# Input image shape: (1, 32, 32, 3)
# 283.png
# Input image shape: (1, 32, 32, 3)
# 284.png
# Input image shape: (1, 32, 32, 3)
# 285.png
# Input image shape: (1, 32, 32, 3)
# 286.png
# Input image shape: (1, 32, 32, 3)
# 287.png
# Input image shape: (1, 32, 32, 3)
# 288.png
# Input image shape: (1, 32, 32, 3)
# 289.png
# Input image shape: (1, 32, 32, 3)
# 290.png
# Input image shape: (1, 32, 32, 3)
# 291.png
# Input image shape: (1, 32, 32, 3)
# 292.png
# Input image shape: (1, 32, 32, 3)
# 293.png
# Input image shape: (1, 32, 32, 3)
# 294.png
# Input image shape: (1, 32, 32, 3)
# 295.png
# Input image shape: (1, 32, 32, 3)
# 296.png
# Input image shape: (1, 32, 32, 3)
# 297.png
# Input image shape: (1, 32, 32, 3)
# 298.png
# Input image shape: (1, 32, 32, 3)
# 299.png
# Input image shape: (1, 32, 32, 3)
# 300.png
# Input image shape: (1, 32, 32, 3)
# 301.png
# Input image shape: (1, 32, 32, 3)
# 302.png
# Input image shape: (1, 32, 32, 3)
# 303.png
# Input image shape: (1, 32, 32, 3)
# 304.png
# Input image shape: (1, 32, 32, 3)
# 305.png
# Input image shape: (1, 32, 32, 3)
# 306.png
# Input image shape: (1, 32, 32, 3)
# 307.png
# Input image shape: (1, 32, 32, 3)
# 308.png
# Input image shape: (1, 32, 32, 3)
# 309.png
# Input image shape: (1, 32, 32, 3)
# 310.png
# Input image shape: (1, 32, 32, 3)
# 311.png
# Input image shape: (1, 32, 32, 3)
# 313.png
# Input image shape: (1, 32, 32, 3)
# 314.png
# Input image shape: (1, 32, 32, 3)
# 315.png
# Input image shape: (1, 32, 32, 3)
# 316.png
# Input image shape: (1, 32, 32, 3)
# 317.png
# Input image shape: (1, 32, 32, 3)
# 318.png
# Input image shape: (1, 32, 32, 3)
# 319.png
# Input image shape: (1, 32, 32, 3)
# 320.png
# Input image shape: (1, 32, 32, 3)
# 321.png
# Input image shape: (1, 32, 32, 3)
# 322.png
# Input image shape: (1, 32, 32, 3)
# 323.png
# Input image shape: (1, 32, 32, 3)
# 324.png
# Input image shape: (1, 32, 32, 3)
# 325.png
# Input image shape: (1, 32, 32, 3)
# 326.png
# Input image shape: (1, 32, 32, 3)
# 327.png
# Input image shape: (1, 32, 32, 3)
# 328.png
# Input image shape: (1, 32, 32, 3)
# 329.png
# Input image shape: (1, 32, 32, 3)
# 331.png
# Input image shape: (1, 32, 32, 3)
# 333.png
# Input image shape: (1, 32, 32, 3)
# 334.png
# Input image shape: (1, 32, 32, 3)
# 335.png
# Input image shape: (1, 32, 32, 3)
# 336.png
# Input image shape: (1, 32, 32, 3)
# 337.png
# Input image shape: (1, 32, 32, 3)
# 338.png
# Input image shape: (1, 32, 32, 3)
# 339.png
# Input image shape: (1, 32, 32, 3)
# 341.png
# Input image shape: (1, 32, 32, 3)
# 342.png
# Input image shape: (1, 32, 32, 3)
# 343.png
# Input image shape: (1, 32, 32, 3)
# 344.png
# Input image shape: (1, 32, 32, 3)
# 345.png
# Input image shape: (1, 32, 32, 3)
# 346.png
# Input image shape: (1, 32, 32, 3)
# 347.png
# Input image shape: (1, 32, 32, 3)
# 348.png
# Input image shape: (1, 32, 32, 3)
# 350.png
# Input image shape: (1, 32, 32, 3)
# 351.png
# Input image shape: (1, 32, 32, 3)
# 352.png
# Input image shape: (1, 32, 32, 3)
# 353.png
# Input image shape: (1, 32, 32, 3)
# 354.png
# Input image shape: (1, 32, 32, 3)
# 355.png
# Input image shape: (1, 32, 32, 3)
# 356.png
# Input image shape: (1, 32, 32, 3)
# 357.png
# Input image shape: (1, 32, 32, 3)
# 358.png
# Input image shape: (1, 32, 32, 3)
# 360.png
# Input image shape: (1, 32, 32, 3)
# 362.png
# Input image shape: (1, 32, 32, 3)
# 363.png
# Input image shape: (1, 32, 32, 3)
# 364.png
# Input image shape: (1, 32, 32, 3)
# 365.png
# Input image shape: (1, 32, 32, 3)
# 366.png
# Input image shape: (1, 32, 32, 3)
# 367.png
# Input image shape: (1, 32, 32, 3)
# 368.png
# Input image shape: (1, 32, 32, 3)
# 369.png
# Input image shape: (1, 32, 32, 3)
# 370.png
# Input image shape: (1, 32, 32, 3)
# 371.png
# Input image shape: (1, 32, 32, 3)
# 373.png
# Input image shape: (1, 32, 32, 3)
# 374.png
# Input image shape: (1, 32, 32, 3)
# 375.png
# Input image shape: (1, 32, 32, 3)
# 376.png
# Input image shape: (1, 32, 32, 3)
# 377.png
# Input image shape: (1, 32, 32, 3)
# 378.png
# Input image shape: (1, 32, 32, 3)
# 379.png
# Input image shape: (1, 32, 32, 3)
# 380.png
# Input image shape: (1, 32, 32, 3)
# 381.png
# Input image shape: (1, 32, 32, 3)
# 382.png
# Input image shape: (1, 32, 32, 3)
# 383.png
# Input image shape: (1, 32, 32, 3)
# 384.png
# Input image shape: (1, 32, 32, 3)
# 385.png
# Input image shape: (1, 32, 32, 3)
# 386.png
# Input image shape: (1, 32, 32, 3)
# 387.png
# Input image shape: (1, 32, 32, 3)
# 388.png
# Input image shape: (1, 32, 32, 3)
# 389.png
# Input image shape: (1, 32, 32, 3)
# 390.png
# Input image shape: (1, 32, 32, 3)
# 391.png
# Input image shape: (1, 32, 32, 3)
# 394.png
# Input image shape: (1, 32, 32, 3)
# 395.png
# Input image shape: (1, 32, 32, 3)
# 396.png
# Input image shape: (1, 32, 32, 3)
# 397.png
# Input image shape: (1, 32, 32, 3)
# 398.png
# Input image shape: (1, 32, 32, 3)
# 399.png
# Input image shape: (1, 32, 32, 3)
# 400.png
# Input image shape: (1, 32, 32, 3)
# 401.png
# Input image shape: (1, 32, 32, 3)
# 402.png
# Input image shape: (1, 32, 32, 3)
# 403.png
# Input image shape: (1, 32, 32, 3)
# 404.png
# Input image shape: (1, 32, 32, 3)
# 405.png
# Input image shape: (1, 32, 32, 3)
# 406.png
# Input image shape: (1, 32, 32, 3)
# 407.png
# Input image shape: (1, 32, 32, 3)
# 408.png
# Input image shape: (1, 32, 32, 3)
# 409.png
# Input image shape: (1, 32, 32, 3)
# 410.png
# Input image shape: (1, 32, 32, 3)
# 411.png
# Input image shape: (1, 32, 32, 3)
# 412.png
# Input image shape: (1, 32, 32, 3)
# 414.png
# Input image shape: (1, 32, 32, 3)
# 415.png
# Input image shape: (1, 32, 32, 3)
# 416.png
# Input image shape: (1, 32, 32, 3)
# 417.png
# Input image shape: (1, 32, 32, 3)
# 418.png
# Input image shape: (1, 32, 32, 3)
# 419.png
# Input image shape: (1, 32, 32, 3)
# 420.png
# Input image shape: (1, 32, 32, 3)
# 421.png
# Input image shape: (1, 32, 32, 3)
# 422.png
# Input image shape: (1, 32, 32, 3)
# 423.png
# Input image shape: (1, 32, 32, 3)
# 424.png
# Input image shape: (1, 32, 32, 3)
# 425.png
# Input image shape: (1, 32, 32, 3)
# 426.png
# Input image shape: (1, 32, 32, 3)
# 430.png
# Input image shape: (1, 32, 32, 3)
# 431.png
# Input image shape: (1, 32, 32, 3)
# 432.png
# Input image shape: (1, 32, 32, 3)
# 433.png
# Input image shape: (1, 32, 32, 3)
# 434.png
# Input image shape: (1, 32, 32, 3)
# 435.png
# Input image shape: (1, 32, 32, 3)
# 436.png
# Input image shape: (1, 32, 32, 3)
# 437.png
# Input image shape: (1, 32, 32, 3)
# 438.png
# Input image shape: (1, 32, 32, 3)
# 439.png
# Input image shape: (1, 32, 32, 3)
# 440.png
# Input image shape: (1, 32, 32, 3)
# 441.png
# Input image shape: (1, 32, 32, 3)
# 442.png
# Input image shape: (1, 32, 32, 3)
# 443.png
# Input image shape: (1, 32, 32, 3)
# 444.png
# Input image shape: (1, 32, 32, 3)
# 445.png
# Input image shape: (1, 32, 32, 3)
# 446.png
# Input image shape: (1, 32, 32, 3)
# 447.png
# Input image shape: (1, 32, 32, 3)
# 448.png
# Input image shape: (1, 32, 32, 3)
# 449.png
# Input image shape: (1, 32, 32, 3)
# 450.png
# Input image shape: (1, 32, 32, 3)
# 451.png
# Input image shape: (1, 32, 32, 3)
# 452.png
# Input image shape: (1, 32, 32, 3)
# 453.png
# Input image shape: (1, 32, 32, 3)
# 454.png
# Input image shape: (1, 32, 32, 3)
# 455.png
# Input image shape: (1, 32, 32, 3)
# 456.png
# Input image shape: (1, 32, 32, 3)
# 457.png
# Input image shape: (1, 32, 32, 3)
# 458.png
# Input image shape: (1, 32, 32, 3)
# 459.png
# Input image shape: (1, 32, 32, 3)
# 460.png
# Input image shape: (1, 32, 32, 3)
# 461.png
# Input image shape: (1, 32, 32, 3)
# 462.png
# Input image shape: (1, 32, 32, 3)
# 463.png
# Input image shape: (1, 32, 32, 3)
# 464.png
# Input image shape: (1, 32, 32, 3)
# 465.png
# Input image shape: (1, 32, 32, 3)
# 466.png
# Input image shape: (1, 32, 32, 3)
# 467.png
# Input image shape: (1, 32, 32, 3)
# 468.png
# Input image shape: (1, 32, 32, 3)
# 469.png
# Input image shape: (1, 32, 32, 3)
# 470.png
# Input image shape: (1, 32, 32, 3)
# 471.png
# Input image shape: (1, 32, 32, 3)
# 472.png
# Input image shape: (1, 32, 32, 3)
# 473.png
# Input image shape: (1, 32, 32, 3)
# 474.png
# Input image shape: (1, 32, 32, 3)
# 475.png
# Input image shape: (1, 32, 32, 3)
# 476.png
# Input image shape: (1, 32, 32, 3)
# 477.png
# Input image shape: (1, 32, 32, 3)
# 478.png
# Input image shape: (1, 32, 32, 3)
# 479.png
# Input image shape: (1, 32, 32, 3)
# 480.png
# Input image shape: (1, 32, 32, 3)
# 481.png
# Input image shape: (1, 32, 32, 3)
# 482.png
# Input image shape: (1, 32, 32, 3)
# 483.png
# Input image shape: (1, 32, 32, 3)
# 484.png
# Input image shape: (1, 32, 32, 3)
# 485.png
# Input image shape: (1, 32, 32, 3)
# 486.png
# Input image shape: (1, 32, 32, 3)
# 487.png
# Input image shape: (1, 32, 32, 3)
# 488.png
# Input image shape: (1, 32, 32, 3)
# 489.png
# Input image shape: (1, 32, 32, 3)
# 490.png
# Input image shape: (1, 32, 32, 3)
# 493.png
# Input image shape: (1, 32, 32, 3)
# 494.png
# Input image shape: (1, 32, 32, 3)
# 495.png
# Input image shape: (1, 32, 32, 3)
# 496.png
# Input image shape: (1, 32, 32, 3)
# 497.png
# Input image shape: (1, 32, 32, 3)
# 498.png
# Input image shape: (1, 32, 32, 3)
# 501.png
# Input image shape: (1, 32, 32, 3)
# 502.png
# Input image shape: (1, 32, 32, 3)
# 503.png
# Input image shape: (1, 32, 32, 3)
# 504.png
# Input image shape: (1, 32, 32, 3)
# 505.png
# Input image shape: (1, 32, 32, 3)
# 506.png
# Input image shape: (1, 32, 32, 3)
# 508.png
# Input image shape: (1, 32, 32, 3)
# 509.png
# Input image shape: (1, 32, 32, 3)
# 510.png
# Input image shape: (1, 32, 32, 3)
# 512.png
# Input image shape: (1, 32, 32, 3)
# 517.png
# Input image shape: (1, 32, 32, 3)
# 518.png
# Input image shape: (1, 32, 32, 3)
# 519.png
# Input image shape: (1, 32, 32, 3)
# 520.png
# Input image shape: (1, 32, 32, 3)
# 521.png
# Input image shape: (1, 32, 32, 3)
# 522.png
# Input image shape: (1, 32, 32, 3)
# 523.png
# Input image shape: (1, 32, 32, 3)
# 524.png
# Input image shape: (1, 32, 32, 3)
# 525.png
# Input image shape: (1, 32, 32, 3)
# 526.png
# Input image shape: (1, 32, 32, 3)
# 527.png
# Input image shape: (1, 32, 32, 3)
# 528.png
# Input image shape: (1, 32, 32, 3)
# 529.png
# Input image shape: (1, 32, 32, 3)
# 530.png
# Input image shape: (1, 32, 32, 3)
# 531.png
# Input image shape: (1, 32, 32, 3)
# 532.png
# Input image shape: (1, 32, 32, 3)
# 533.png
# Input image shape: (1, 32, 32, 3)
# 534.png
# Input image shape: (1, 32, 32, 3)
# 535.png
# Input image shape: (1, 32, 32, 3)
# 536.png
# Input image shape: (1, 32, 32, 3)
# 537.png
# Input image shape: (1, 32, 32, 3)
# 538.png
# Input image shape: (1, 32, 32, 3)
# 539.png
# Input image shape: (1, 32, 32, 3)
# 543.png
# Input image shape: (1, 32, 32, 3)
# 544.png
# Input image shape: (1, 32, 32, 3)
# 545.png
# Input image shape: (1, 32, 32, 3)
# 546.png
# Input image shape: (1, 32, 32, 3)
# 547.png
# Input image shape: (1, 32, 32, 3)
# 548.png
# Input image shape: (1, 32, 32, 3)
# 549.png
# Input image shape: (1, 32, 32, 3)
# 550.png
# Input image shape: (1, 32, 32, 3)
# 551.png
# Input image shape: (1, 32, 32, 3)
# 554.png
# Input image shape: (1, 32, 32, 3)
# 555.png
# Input image shape: (1, 32, 32, 3)
# 556.png
# Input image shape: (1, 32, 32, 3)
# 557.png
# Input image shape: (1, 32, 32, 3)
# 558.png
# Input image shape: (1, 32, 32, 3)
# 559.png
# Input image shape: (1, 32, 32, 3)
# 560.png
# Input image shape: (1, 32, 32, 3)
# 561.png
# Input image shape: (1, 32, 32, 3)
# 562.png
# Input image shape: (1, 32, 32, 3)
# 563.png
# Input image shape: (1, 32, 32, 3)
# 564.png
# Input image shape: (1, 32, 32, 3)
# 565.png
# Input image shape: (1, 32, 32, 3)
# 566.png
# Input image shape: (1, 32, 32, 3)
# 567.png
# Input image shape: (1, 32, 32, 3)
# 568.png
# Input image shape: (1, 32, 32, 3)
# 569.png
# Input image shape: (1, 32, 32, 3)
# 570.png
# Input image shape: (1, 32, 32, 3)
# 571.png
# Input image shape: (1, 32, 32, 3)
# 572.png
# Input image shape: (1, 32, 32, 3)
# 573.png
# Input image shape: (1, 32, 32, 3)
# 574.png
# Input image shape: (1, 32, 32, 3)
# 575.png
# Input image shape: (1, 32, 32, 3)
# 576.png
# Input image shape: (1, 32, 32, 3)
# 577.png
# Input image shape: (1, 32, 32, 3)
# 578.png
# Input image shape: (1, 32, 32, 3)
# 579.png
# Input image shape: (1, 32, 32, 3)
# 580.png
# Input image shape: (1, 32, 32, 3)
# 581.png
# Input image shape: (1, 32, 32, 3)
# 582.png
# Input image shape: (1, 32, 32, 3)
# 583.png
# Input image shape: (1, 32, 32, 3)
# 584.png
# Input image shape: (1, 32, 32, 3)
# 585.png
# Input image shape: (1, 32, 32, 3)
# 586.png
# Input image shape: (1, 32, 32, 3)
# 587.png
# Input image shape: (1, 32, 32, 3)
# 588.png
# Input image shape: (1, 32, 32, 3)
# 589.png
# Input image shape: (1, 32, 32, 3)
# 590.png
# Input image shape: (1, 32, 32, 3)
# 591.png
# Input image shape: (1, 32, 32, 3)
# 592.png
# Input image shape: (1, 32, 32, 3)
# 593.png
# Input image shape: (1, 32, 32, 3)
# 594.png
# Input image shape: (1, 32, 32, 3)
# 595.png
# Input image shape: (1, 32, 32, 3)
# 596.png
# Input image shape: (1, 32, 32, 3)
# 597.png
# Input image shape: (1, 32, 32, 3)
# 598.png
# Input image shape: (1, 32, 32, 3)
# 599.png
# Input image shape: (1, 32, 32, 3)
# 600.png
# Input image shape: (1, 32, 32, 3)
# 601.png
# Input image shape: (1, 32, 32, 3)
# 602.png
# Input image shape: (1, 32, 32, 3)
# 603.png
# Input image shape: (1, 32, 32, 3)
# 604.png
# Input image shape: (1, 32, 32, 3)
# 605.png
# Input image shape: (1, 32, 32, 3)
# 606.png
# Input image shape: (1, 32, 32, 3)
# 607.png
# Input image shape: (1, 32, 32, 3)
# 608.png
# Input image shape: (1, 32, 32, 3)
# 609.png
# Input image shape: (1, 32, 32, 3)
# 610.png
# Input image shape: (1, 32, 32, 3)
# 611.png
# Input image shape: (1, 32, 32, 3)
# 612.png
# Input image shape: (1, 32, 32, 3)
# 613.png
# Input image shape: (1, 32, 32, 3)
# 614.png
# Input image shape: (1, 32, 32, 3)
# 615.png
# Input image shape: (1, 32, 32, 3)
# 616.png
# Input image shape: (1, 32, 32, 3)
# 617.png
# Input image shape: (1, 32, 32, 3)
# 618.png
# Input image shape: (1, 32, 32, 3)
# 619.png
# Input image shape: (1, 32, 32, 3)
# 620.png
# Input image shape: (1, 32, 32, 3)
# 621.png
# Input image shape: (1, 32, 32, 3)
# 622.png
# Input image shape: (1, 32, 32, 3)
# 623.png
# Input image shape: (1, 32, 32, 3)
# 624.png
# Input image shape: (1, 32, 32, 3)
# 625.png
# Input image shape: (1, 32, 32, 3)
# 626.png
# Input image shape: (1, 32, 32, 3)
# 627.png
# Input image shape: (1, 32, 32, 3)
# 628.png
# Input image shape: (1, 32, 32, 3)
# 629.png
# Input image shape: (1, 32, 32, 3)
# 630.png
# Input image shape: (1, 32, 32, 3)
# 631.png
# Input image shape: (1, 32, 32, 3)
# 632.png
# Input image shape: (1, 32, 32, 3)
# 633.png
# Input image shape: (1, 32, 32, 3)
# 634.png
# Input image shape: (1, 32, 32, 3)
# 635.png
# Input image shape: (1, 32, 32, 3)
# 636.png
# Input image shape: (1, 32, 32, 3)
# 637.png
# Input image shape: (1, 32, 32, 3)
# 638.png
# Input image shape: (1, 32, 32, 3)
# 639.png
# Input image shape: (1, 32, 32, 3)
# 640.png
# Input image shape: (1, 32, 32, 3)
# 641.png
# Input image shape: (1, 32, 32, 3)
# 642.png
# Input image shape: (1, 32, 32, 3)
# 643.png
# Input image shape: (1, 32, 32, 3)
# 644.png
# Input image shape: (1, 32, 32, 3)
# 645.png
# Input image shape: (1, 32, 32, 3)
# 646.png
# Input image shape: (1, 32, 32, 3)
# 647.png
# Input image shape: (1, 32, 32, 3)
# 648.png
# Input image shape: (1, 32, 32, 3)
# 649.png
# Input image shape: (1, 32, 32, 3)
# 650.png
# Input image shape: (1, 32, 32, 3)
# 651.png
# Input image shape: (1, 32, 32, 3)
# 652.png
# Input image shape: (1, 32, 32, 3)
# 653.png
# Input image shape: (1, 32, 32, 3)
# 654.png
# Input image shape: (1, 32, 32, 3)
# 655.png
# Input image shape: (1, 32, 32, 3)
# 656.png
# Input image shape: (1, 32, 32, 3)
# 657.png
# Input image shape: (1, 32, 32, 3)
# 660.png
# Input image shape: (1, 32, 32, 3)
# 662.png
# Input image shape: (1, 32, 32, 3)
# 663.png
# Input image shape: (1, 32, 32, 3)
# 664.png
# Input image shape: (1, 32, 32, 3)
# 665.png
# Input image shape: (1, 32, 32, 3)
# 666.png
# Input image shape: (1, 32, 32, 3)
# 667.png
# Input image shape: (1, 32, 32, 3)
# 669.png
# Input image shape: (1, 32, 32, 3)
# 670.png
# Input image shape: (1, 32, 32, 3)
# 671.png
# Input image shape: (1, 32, 32, 3)
# 672.png
# Input image shape: (1, 32, 32, 3)
# 674.png
# Input image shape: (1, 32, 32, 3)
# 675.png
# Input image shape: (1, 32, 32, 3)
# 676.png
# Input image shape: (1, 32, 32, 3)
# 677.png
# Input image shape: (1, 32, 32, 3)
# 678.png
# Input image shape: (1, 32, 32, 3)
# 679.png
# Input image shape: (1, 32, 32, 3)
# 680.png
# Input image shape: (1, 32, 32, 3)
# 681.png
# Input image shape: (1, 32, 32, 3)
# 682.png
# Input image shape: (1, 32, 32, 3)
# 683.png
# Input image shape: (1, 32, 32, 3)
# 684.png
# Input image shape: (1, 32, 32, 3)
# 685.png
# Input image shape: (1, 32, 32, 3)
# 687.png
# Input image shape: (1, 32, 32, 3)
# 688.png
# Input image shape: (1, 32, 32, 3)
# 689.png
# Input image shape: (1, 32, 32, 3)
# 690.png
# Input image shape: (1, 32, 32, 3)
# 691.png
# Input image shape: (1, 32, 32, 3)
# 692.png
# Input image shape: (1, 32, 32, 3)
# 693.png
# Input image shape: (1, 32, 32, 3)
# 694.png
# Input image shape: (1, 32, 32, 3)
# 695.png
# Input image shape: (1, 32, 32, 3)
# 697.png
# Input image shape: (1, 32, 32, 3)
# 698.png
# Input image shape: (1, 32, 32, 3)
# 699.png
# Input image shape: (1, 32, 32, 3)
# 700.png
# Input image shape: (1, 32, 32, 3)
# 701.png
# Input image shape: (1, 32, 32, 3)
# 702.png
# Input image shape: (1, 32, 32, 3)
# 703.png
# Input image shape: (1, 32, 32, 3)
# 704.png
# Input image shape: (1, 32, 32, 3)
# 705.png
# Input image shape: (1, 32, 32, 3)
# 706.png
# Input image shape: (1, 32, 32, 3)
# 707.png
# Input image shape: (1, 32, 32, 3)
# 708.png
# Input image shape: (1, 32, 32, 3)
# 709.png
# Input image shape: (1, 32, 32, 3)
# 710.png
# Input image shape: (1, 32, 32, 3)
# 711.png
# Input image shape: (1, 32, 32, 3)
# 712.png
# Input image shape: (1, 32, 32, 3)
# 714.png
# Input image shape: (1, 32, 32, 3)
# 715.png
# Input image shape: (1, 32, 32, 3)
# 716.png
# Input image shape: (1, 32, 32, 3)
# 717.png
# Input image shape: (1, 32, 32, 3)
# 718.png
# Input image shape: (1, 32, 32, 3)
# 719.png
# Input image shape: (1, 32, 32, 3)
# 720.png
# Input image shape: (1, 32, 32, 3)
# 721.png
# Input image shape: (1, 32, 32, 3)
# 723.png
# Input image shape: (1, 32, 32, 3)
# 724.png
# Input image shape: (1, 32, 32, 3)
# 725.png
# Input image shape: (1, 32, 32, 3)
# 726.png
# Input image shape: (1, 32, 32, 3)
# 727.png
# Input image shape: (1, 32, 32, 3)
# 728.png
# Input image shape: (1, 32, 32, 3)
# 729.png
# Input image shape: (1, 32, 32, 3)
# 730.png
# Input image shape: (1, 32, 32, 3)
# 731.png
# Input image shape: (1, 32, 32, 3)
# 732.png
# Input image shape: (1, 32, 32, 3)
# 733.png
# Input image shape: (1, 32, 32, 3)
# 734.png
# Input image shape: (1, 32, 32, 3)
# 735.png
# Input image shape: (1, 32, 32, 3)
# 736.png
# Input image shape: (1, 32, 32, 3)
# 737.png
# Input image shape: (1, 32, 32, 3)
# 738.png
# Input image shape: (1, 32, 32, 3)
# 739.png
# Input image shape: (1, 32, 32, 3)
# 740.png
# Input image shape: (1, 32, 32, 3)
# 741.png
# Input image shape: (1, 32, 32, 3)
# 742.png
# Input image shape: (1, 32, 32, 3)
# 743.png
# Input image shape: (1, 32, 32, 3)
# 744.png
# Input image shape: (1, 32, 32, 3)
# 745.png
# Input image shape: (1, 32, 32, 3)
# 746.png
# Input image shape: (1, 32, 32, 3)
# 747.png
# Input image shape: (1, 32, 32, 3)
# 748.png
# Input image shape: (1, 32, 32, 3)
# 749.png
# Input image shape: (1, 32, 32, 3)
# 751.png
# Input image shape: (1, 32, 32, 3)
# 752.png
# Input image shape: (1, 32, 32, 3)
# 753.png
# Input image shape: (1, 32, 32, 3)
# 754.png
# Input image shape: (1, 32, 32, 3)
# 755.png
# Input image shape: (1, 32, 32, 3)
# 756.png
# Input image shape: (1, 32, 32, 3)
# 757.png
# Input image shape: (1, 32, 32, 3)
# 758.png
# Input image shape: (1, 32, 32, 3)
# 759.png
# Input image shape: (1, 32, 32, 3)
# 760.png
# Input image shape: (1, 32, 32, 3)
# 763.png
# Input image shape: (1, 32, 32, 3)
# 764.png
# Input image shape: (1, 32, 32, 3)
# 765.png
# Input image shape: (1, 32, 32, 3)
# 767.png
# Input image shape: (1, 32, 32, 3)
# 768.png
# Input image shape: (1, 32, 32, 3)
# 769.png
# Input image shape: (1, 32, 32, 3)
# 770.png
# Input image shape: (1, 32, 32, 3)
# 771.png
# Input image shape: (1, 32, 32, 3)
# 772.png
# Input image shape: (1, 32, 32, 3)
# 773.png
# Input image shape: (1, 32, 32, 3)
# 774.png
# Input image shape: (1, 32, 32, 3)
# 775.png
# Input image shape: (1, 32, 32, 3)
# 776.png
# Input image shape: (1, 32, 32, 3)
# 777.png
# Input image shape: (1, 32, 32, 3)
# 778.png
# Input image shape: (1, 32, 32, 3)
# 779.png
# Input image shape: (1, 32, 32, 3)
# 780.png
# Input image shape: (1, 32, 32, 3)
# 781.png
# Input image shape: (1, 32, 32, 3)
# 782.png
# Input image shape: (1, 32, 32, 3)
# 785.png
# Input image shape: (1, 32, 32, 3)
# 786.png
# Input image shape: (1, 32, 32, 3)
# 787.png
# Input image shape: (1, 32, 32, 3)
# 788.png
# Input image shape: (1, 32, 32, 3)
# 789.png
# Input image shape: (1, 32, 32, 3)
# 790.png
# Input image shape: (1, 32, 32, 3)
# 791.png
# Input image shape: (1, 32, 32, 3)
# 792.png
# Input image shape: (1, 32, 32, 3)
# 793.png
# Input image shape: (1, 32, 32, 3)
# 794.png
# Input image shape: (1, 32, 32, 3)
# 795.png
# Input image shape: (1, 32, 32, 3)
# 796.png
# Input image shape: (1, 32, 32, 3)
# 797.png
# Input image shape: (1, 32, 32, 3)
# 798.png
# Input image shape: (1, 32, 32, 3)
# 799.png
# Input image shape: (1, 32, 32, 3)
# 800.png
# Input image shape: (1, 32, 32, 3)
# 801.png
# Input image shape: (1, 32, 32, 3)
# 802.png
# Input image shape: (1, 32, 32, 3)
# 803.png
# Input image shape: (1, 32, 32, 3)
# 804.png
# Input image shape: (1, 32, 32, 3)
# 805.png
# Input image shape: (1, 32, 32, 3)
# 806.png
# Input image shape: (1, 32, 32, 3)
# 807.png
# Input image shape: (1, 32, 32, 3)
# 808.png
# Input image shape: (1, 32, 32, 3)
# 809.png
# Input image shape: (1, 32, 32, 3)
# 811.png
# Input image shape: (1, 32, 32, 3)
# 812.png
# Input image shape: (1, 32, 32, 3)
# 813.png
# Input image shape: (1, 32, 32, 3)
# 814.png
# Input image shape: (1, 32, 32, 3)
# 815.png
# Input image shape: (1, 32, 32, 3)
# 816.png
# Input image shape: (1, 32, 32, 3)
# 817.png
# Input image shape: (1, 32, 32, 3)
# 818.png
# Input image shape: (1, 32, 32, 3)
# 820.png
# Input image shape: (1, 32, 32, 3)
# 821.png
# Input image shape: (1, 32, 32, 3)
# 822.png
# Input image shape: (1, 32, 32, 3)
# 823.png
# Input image shape: (1, 32, 32, 3)
# 824.png
# Input image shape: (1, 32, 32, 3)
# 825.png
# Input image shape: (1, 32, 32, 3)
# 826.png
# Input image shape: (1, 32, 32, 3)
# 827.png
# Input image shape: (1, 32, 32, 3)
# 828.png
# Input image shape: (1, 32, 32, 3)
# 830.png
# Input image shape: (1, 32, 32, 3)
# 831.png
# Input image shape: (1, 32, 32, 3)
# 832.png
# Input image shape: (1, 32, 32, 3)
# 833.png
# Input image shape: (1, 32, 32, 3)
# 834.png
# Input image shape: (1, 32, 32, 3)
# 835.png
# Input image shape: (1, 32, 32, 3)
# 836.png
# Input image shape: (1, 32, 32, 3)
# 837.png
# Input image shape: (1, 32, 32, 3)
# 838.png
# Input image shape: (1, 32, 32, 3)
# 839.png
# Input image shape: (1, 32, 32, 3)
# 840.png
# Input image shape: (1, 32, 32, 3)
# 841.png
# Input image shape: (1, 32, 32, 3)
# 842.png
# Input image shape: (1, 32, 32, 3)
# 844.png
# Input image shape: (1, 32, 32, 3)
# 845.png
# Input image shape: (1, 32, 32, 3)
# 846.png
# Input image shape: (1, 32, 32, 3)
# 847.png
# Input image shape: (1, 32, 32, 3)
# 848.png
# Input image shape: (1, 32, 32, 3)
# 849.png
# Input image shape: (1, 32, 32, 3)
# 850.png
# Input image shape: (1, 32, 32, 3)
# 851.png
# Input image shape: (1, 32, 32, 3)
# 852.png
# Input image shape: (1, 32, 32, 3)
# 853.png
# Input image shape: (1, 32, 32, 3)
# 854.png
# Input image shape: (1, 32, 32, 3)
# 855.png
# Input image shape: (1, 32, 32, 3)
# 856.png
# Input image shape: (1, 32, 32, 3)
# 857.png
# Input image shape: (1, 32, 32, 3)
# 858.png
# Input image shape: (1, 32, 32, 3)
# 860.png
# Input image shape: (1, 32, 32, 3)
# 863.png
# Input image shape: (1, 32, 32, 3)
# 864.png
# Input image shape: (1, 32, 32, 3)
# 865.png
# Input image shape: (1, 32, 32, 3)
# 866.png
# Input image shape: (1, 32, 32, 3)
# 867.png
# Input image shape: (1, 32, 32, 3)
# 868.png
# Input image shape: (1, 32, 32, 3)
# 869.png
# Input image shape: (1, 32, 32, 3)
# 871.png
# Input image shape: (1, 32, 32, 3)
# 872.png
# Input image shape: (1, 32, 32, 3)
# 873.png
# Input image shape: (1, 32, 32, 3)
# 874.png
# Input image shape: (1, 32, 32, 3)
# 875.png
# Input image shape: (1, 32, 32, 3)
# 876.png
# Input image shape: (1, 32, 32, 3)
# 877.png
# Input image shape: (1, 32, 32, 3)
# 878.png
# Input image shape: (1, 32, 32, 3)
# 879.png
# Input image shape: (1, 32, 32, 3)
# 880.png
# Input image shape: (1, 32, 32, 3)
# 881.png
# Input image shape: (1, 32, 32, 3)
# 882.png
# Input image shape: (1, 32, 32, 3)
# 883.png
# Input image shape: (1, 32, 32, 3)
# 884.png
# Input image shape: (1, 32, 32, 3)
# 885.png
# Input image shape: (1, 32, 32, 3)
# 887.png
# Input image shape: (1, 32, 32, 3)
# 888.png
# Input image shape: (1, 32, 32, 3)
# 889.png
# Input image shape: (1, 32, 32, 3)
# 890.png
# Input image shape: (1, 32, 32, 3)
# 891.png
# Input image shape: (1, 32, 32, 3)
# 892.png
# Input image shape: (1, 32, 32, 3)
# 893.png
# Input image shape: (1, 32, 32, 3)
# 894.png
# Input image shape: (1, 32, 32, 3)
# 895.png
# Input image shape: (1, 32, 32, 3)
# 896.png
# Input image shape: (1, 32, 32, 3)
# 897.png
# Input image shape: (1, 32, 32, 3)
# 898.png
# Input image shape: (1, 32, 32, 3)
# 899.png
# Input image shape: (1, 32, 32, 3)
# 900.png
# Input image shape: (1, 32, 32, 3)
# 901.png
# Input image shape: (1, 32, 32, 3)
# 902.png
# Input image shape: (1, 32, 32, 3)
# 903.png
# Input image shape: (1, 32, 32, 3)
# 904.png
# Input image shape: (1, 32, 32, 3)
# 905.png
# Input image shape: (1, 32, 32, 3)
# 906.png
# Input image shape: (1, 32, 32, 3)
# 908.png
# Input image shape: (1, 32, 32, 3)
# 909.png
# Input image shape: (1, 32, 32, 3)
# 910.png
# Input image shape: (1, 32, 32, 3)
# 911.png
# Input image shape: (1, 32, 32, 3)
# 912.png
# Input image shape: (1, 32, 32, 3)
# 913.png
# Input image shape: (1, 32, 32, 3)
# 914.png
# Input image shape: (1, 32, 32, 3)
# 915.png
# Input image shape: (1, 32, 32, 3)
# 916.png
# Input image shape: (1, 32, 32, 3)
# 917.png
# Input image shape: (1, 32, 32, 3)
# 918.png
# Input image shape: (1, 32, 32, 3)
# 919.png
# Input image shape: (1, 32, 32, 3)
# 920.png
# Input image shape: (1, 32, 32, 3)
# 921.png
# Input image shape: (1, 32, 32, 3)
# 922.png
# Input image shape: (1, 32, 32, 3)
# 923.png
# Input image shape: (1, 32, 32, 3)
# 924.png
# Input image shape: (1, 32, 32, 3)
# 925.png
# Input image shape: (1, 32, 32, 3)
# 926.png
# Input image shape: (1, 32, 32, 3)
# 927.png
# Input image shape: (1, 32, 32, 3)
# 928.png
# Input image shape: (1, 32, 32, 3)
# 929.png
# Input image shape: (1, 32, 32, 3)
# 930.png
# Input image shape: (1, 32, 32, 3)
# 931.png
# Input image shape: (1, 32, 32, 3)
# 932.png
# Input image shape: (1, 32, 32, 3)
# 933.png
# Input image shape: (1, 32, 32, 3)
# 934.png
# Input image shape: (1, 32, 32, 3)
# 935.png
# Input image shape: (1, 32, 32, 3)
# 936.png
# Input image shape: (1, 32, 32, 3)
# 937.png
# Input image shape: (1, 32, 32, 3)
# 938.png
# Input image shape: (1, 32, 32, 3)
# 939.png
# Input image shape: (1, 32, 32, 3)
# 940.png
# Input image shape: (1, 32, 32, 3)
# 941.png
# Input image shape: (1, 32, 32, 3)
# 942.png
# Input image shape: (1, 32, 32, 3)
# 943.png
# Input image shape: (1, 32, 32, 3)
# 944.png
# Input image shape: (1, 32, 32, 3)
# 945.png
# Input image shape: (1, 32, 32, 3)
# 946.png
# Input image shape: (1, 32, 32, 3)
# 947.png
# Input image shape: (1, 32, 32, 3)
# 948.png
# Input image shape: (1, 32, 32, 3)
# 949.png
# Input image shape: (1, 32, 32, 3)
# 950.png
# Input image shape: (1, 32, 32, 3)
# 951.png
# Input image shape: (1, 32, 32, 3)
# 952.png
# Input image shape: (1, 32, 32, 3)
# 953.png
# Input image shape: (1, 32, 32, 3)
# 954.png
# Input image shape: (1, 32, 32, 3)
# 955.png
# Input image shape: (1, 32, 32, 3)
# 956.png
# Input image shape: (1, 32, 32, 3)
# 957.png
# Input image shape: (1, 32, 32, 3)
# 958.png
# Input image shape: (1, 32, 32, 3)
# 960.png
# Input image shape: (1, 32, 32, 3)
# 961.png
# Input image shape: (1, 32, 32, 3)
# 962.png
# Input image shape: (1, 32, 32, 3)
# 963.png
# Input image shape: (1, 32, 32, 3)
# 964.png
# Input image shape: (1, 32, 32, 3)
# 965.png
# Input image shape: (1, 32, 32, 3)
# 966.png
# Input image shape: (1, 32, 32, 3)
# 967.png
# Input image shape: (1, 32, 32, 3)
# 970.png
# Input image shape: (1, 32, 32, 3)
# 971.png
# Input image shape: (1, 32, 32, 3)
# 972.png
# Input image shape: (1, 32, 32, 3)
# 973.png
# Input image shape: (1, 32, 32, 3)
# 974.png
# Input image shape: (1, 32, 32, 3)
# 975.png
# Input image shape: (1, 32, 32, 3)
# 976.png
# Input image shape: (1, 32, 32, 3)
# 977.png
# Input image shape: (1, 32, 32, 3)
# 978.png
# Input image shape: (1, 32, 32, 3)
# 979.png
# Input image shape: (1, 32, 32, 3)
# 980.png
# Input image shape: (1, 32, 32, 3)
# 981.png
# Input image shape: (1, 32, 32, 3)
# 982.png
# Input image shape: (1, 32, 32, 3)
# 983.png
# Input image shape: (1, 32, 32, 3)
# 984.png
# Input image shape: (1, 32, 32, 3)
# 985.png
# Input image shape: (1, 32, 32, 3)
# 986.png
# Input image shape: (1, 32, 32, 3)
# 987.png
# Input image shape: (1, 32, 32, 3)
# 988.png
# Input image shape: (1, 32, 32, 3)
# 989.png
# Input image shape: (1, 32, 32, 3)
# 990.png
# Input image shape: (1, 32, 32, 3)
# 991.png
# Input image shape: (1, 32, 32, 3)
# 992.png
# Input image shape: (1, 32, 32, 3)
# 993.png
# Input image shape: (1, 32, 32, 3)
# 994.png
# Input image shape: (1, 32, 32, 3)
# 995.png
# Input image shape: (1, 32, 32, 3)
# 996.png
# Input image shape: (1, 32, 32, 3)
# 997.png
# Input image shape: (1, 32, 32, 3)
# 998.png
# Input image shape: (1, 32, 32, 3)
# 999.png
# Input image shape: (1, 32, 32, 3)
# 1000.png
# Input image shape: (1, 32, 32, 3)
# 1001.png
# Input image shape: (1, 32, 32, 3)
# 1002.png
# Input image shape: (1, 32, 32, 3)
# 1003.png
# Input image shape: (1, 32, 32, 3)
# 1004.png
# Input image shape: (1, 32, 32, 3)
# 1005.png
# Input image shape: (1, 32, 32, 3)
# 1006.png
# Input image shape: (1, 32, 32, 3)
# 1007.png
# Input image shape: (1, 32, 32, 3)
# 1008.png
# Input image shape: (1, 32, 32, 3)
# 1009.png
# Input image shape: (1, 32, 32, 3)
# 1010.png
# Input image shape: (1, 32, 32, 3)
# 1011.png
# Input image shape: (1, 32, 32, 3)
# 1012.png
# Input image shape: (1, 32, 32, 3)
# 1015.png
# Input image shape: (1, 32, 32, 3)
# 1016.png
# Input image shape: (1, 32, 32, 3)
# 1017.png
# Input image shape: (1, 32, 32, 3)
# 1018.png
# Input image shape: (1, 32, 32, 3)
# 1019.png
# Input image shape: (1, 32, 32, 3)
# 1020.png
# Input image shape: (1, 32, 32, 3)
# 1021.png
# Input image shape: (1, 32, 32, 3)
# 1022.png
# Input image shape: (1, 32, 32, 3)
# 1023.png
# Input image shape: (1, 32, 32, 3)
# 1024.png
# Input image shape: (1, 32, 32, 3)
# 1025.png
# Input image shape: (1, 32, 32, 3)
# 1026.png
# Input image shape: (1, 32, 32, 3)
# 1027.png
# Input image shape: (1, 32, 32, 3)
# 1028.png
# Input image shape: (1, 32, 32, 3)
# 1031.png
# Input image shape: (1, 32, 32, 3)
# 1032.png
# Input image shape: (1, 32, 32, 3)
# 1033.png
# Input image shape: (1, 32, 32, 3)
# 1034.png
# Input image shape: (1, 32, 32, 3)
# 1035.png
# Input image shape: (1, 32, 32, 3)
# 1036.png
# Input image shape: (1, 32, 32, 3)
# 1037.png
# Input image shape: (1, 32, 32, 3)
# 1038.png
# Input image shape: (1, 32, 32, 3)
# 1039.png
# Input image shape: (1, 32, 32, 3)
# 1040.png
# Input image shape: (1, 32, 32, 3)
# 1041.png
# Input image shape: (1, 32, 32, 3)
# 1042.png
# Input image shape: (1, 32, 32, 3)
# 1043.png
# Input image shape: (1, 32, 32, 3)
# 1044.png
# Input image shape: (1, 32, 32, 3)
# 1045.png
# Input image shape: (1, 32, 32, 3)
# 1046.png
# Input image shape: (1, 32, 32, 3)
# 1047.png
# Input image shape: (1, 32, 32, 3)
# 1048.png
# Input image shape: (1, 32, 32, 3)
# 1049.png
# Input image shape: (1, 32, 32, 3)
# 1050.png
# Input image shape: (1, 32, 32, 3)
# 1051.png
# Input image shape: (1, 32, 32, 3)
# 1052.png
# Input image shape: (1, 32, 32, 3)
# 1054.png
# Input image shape: (1, 32, 32, 3)
# 1055.png
# Input image shape: (1, 32, 32, 3)
# 1056.png
# Input image shape: (1, 32, 32, 3)
# 1057.png
# Input image shape: (1, 32, 32, 3)
# 1058.png
# Input image shape: (1, 32, 32, 3)
# 1059.png
# Input image shape: (1, 32, 32, 3)
# 1061.png
# Input image shape: (1, 32, 32, 3)
# 1062.png
# Input image shape: (1, 32, 32, 3)
# 1063.png
# Input image shape: (1, 32, 32, 3)
# 1064.png
# Input image shape: (1, 32, 32, 3)
# 1065.png
# Input image shape: (1, 32, 32, 3)
# 1066.png
# Input image shape: (1, 32, 32, 3)
# 1067.png
# Input image shape: (1, 32, 32, 3)
# 1068.png
# Input image shape: (1, 32, 32, 3)
# 1069.png
# Input image shape: (1, 32, 32, 3)
# 1070.png
# Input image shape: (1, 32, 32, 3)
# 1071.png
# Input image shape: (1, 32, 32, 3)
# 1072.png
# Input image shape: (1, 32, 32, 3)
# 1073.png
# Input image shape: (1, 32, 32, 3)
# 1075.png
# Input image shape: (1, 32, 32, 3)
# 1076.png
# Input image shape: (1, 32, 32, 3)
# 1077.png
# Input image shape: (1, 32, 32, 3)
# 1078.png
# Input image shape: (1, 32, 32, 3)
# 1079.png
# Input image shape: (1, 32, 32, 3)
# 1080.png
# Input image shape: (1, 32, 32, 3)
# 1081.png
# Input image shape: (1, 32, 32, 3)
# 1082.png
# Input image shape: (1, 32, 32, 3)
# 1083.png
# Input image shape: (1, 32, 32, 3)
# 1084.png
# Input image shape: (1, 32, 32, 3)
# 1085.png
# Input image shape: (1, 32, 32, 3)
# 1086.png
# Input image shape: (1, 32, 32, 3)
# 1087.png
# Input image shape: (1, 32, 32, 3)
# 1088.png
# Input image shape: (1, 32, 32, 3)
# 1089.png
# Input image shape: (1, 32, 32, 3)
# 1090.png
# Input image shape: (1, 32, 32, 3)
# 1091.png
# Input image shape: (1, 32, 32, 3)
# 1092.png
# Input image shape: (1, 32, 32, 3)
# 1093.png
# Input image shape: (1, 32, 32, 3)
# 1094.png
# Input image shape: (1, 32, 32, 3)
# 1095.png
# Input image shape: (1, 32, 32, 3)
# 1096.png
# Input image shape: (1, 32, 32, 3)
# 1098.png
# Input image shape: (1, 32, 32, 3)
# 1099.png
# Input image shape: (1, 32, 32, 3)
# 1100.png
# Input image shape: (1, 32, 32, 3)
# 1101.png
# Input image shape: (1, 32, 32, 3)
# 1102.png
# Input image shape: (1, 32, 32, 3)
# 1103.png
# Input image shape: (1, 32, 32, 3)
# 1104.png
# Input image shape: (1, 32, 32, 3)
# 1105.png
# Input image shape: (1, 32, 32, 3)
# 1106.png
# Input image shape: (1, 32, 32, 3)
# 1107.png
# Input image shape: (1, 32, 32, 3)
# 1108.png
# Input image shape: (1, 32, 32, 3)
# 1109.png
# Input image shape: (1, 32, 32, 3)
# 1110.png
# Input image shape: (1, 32, 32, 3)
# 1111.png
# Input image shape: (1, 32, 32, 3)
# 1112.png
# Input image shape: (1, 32, 32, 3)
# 1113.png
# Input image shape: (1, 32, 32, 3)
# 1115.png
# Input image shape: (1, 32, 32, 3)
# 1117.png
# Input image shape: (1, 32, 32, 3)
# 1118.png
# Input image shape: (1, 32, 32, 3)
# 1119.png
# Input image shape: (1, 32, 32, 3)
# 1120.png
# Input image shape: (1, 32, 32, 3)
# 1121.png
# Input image shape: (1, 32, 32, 3)
# 1122.png
# Input image shape: (1, 32, 32, 3)
# 1123.png
# Input image shape: (1, 32, 32, 3)
# 1124.png
# Input image shape: (1, 32, 32, 3)
# 1125.png
# Input image shape: (1, 32, 32, 3)
# 1126.png
# Input image shape: (1, 32, 32, 3)
# 1127.png
# Input image shape: (1, 32, 32, 3)
# ...
# 22064.png
# Input image shape: (1, 32, 32, 3)
# 22065.png
# Input image shape: (1, 32, 32, 3)
# 22066.png
# Input image shape: (1, 32, 32, 3)
# 22067.png
# Input image shape: (1, 32, 32, 3)
# 22068.png
# Input image shape: (1, 32, 32, 3)
# 22069.png
# Input image shape: (1, 32, 32, 3)
# 22070.png
# Input image shape: (1, 32, 32, 3)
# 22071.png
# Input image shape: (1, 32, 32, 3)
# 22072.png
# Input image shape: (1, 32, 32, 3)
# 22073.png
# Input image shape: (1, 32, 32, 3)
# 22074.png
# Input image shape: (1, 32, 32, 3)
# 22075.png
# Input image shape: (1, 32, 32, 3)
# 22076.png
# Input image shape: (1, 32, 32, 3)
# 22077.png
# Input image shape: (1, 32, 32, 3)
# 22079.png
# Input image shape: (1, 32, 32, 3)
# 22080.png
# Input image shape: (1, 32, 32, 3)
# 22081.png
# Input image shape: (1, 32, 32, 3)
# 22082.png
# Input image shape: (1, 32, 32, 3)
# 22084.png
# Input image shape: (1, 32, 32, 3)
# 22085.png
# Input image shape: (1, 32, 32, 3)
# 22086.png
# Input image shape: (1, 32, 32, 3)
# 22087.png
# Input image shape: (1, 32, 32, 3)
# 22088.png
# Input image shape: (1, 32, 32, 3)
# 22090.png
# Input image shape: (1, 32, 32, 3)
# 22091.png
# Input image shape: (1, 32, 32, 3)
# 22097.png
# Input image shape: (1, 32, 32, 3)
# 22098.png
# Input image shape: (1, 32, 32, 3)
# 22099.png
# Input image shape: (1, 32, 32, 3)
# 22100.png
# Input image shape: (1, 32, 32, 3)
# 22101.png
# Input image shape: (1, 32, 32, 3)
# 22102.png
# Input image shape: (1, 32, 32, 3)
# 22103.png
# Input image shape: (1, 32, 32, 3)
# 22104.png
# Input image shape: (1, 32, 32, 3)
# 22105.png
# Input image shape: (1, 32, 32, 3)
# 22106.png
# Input image shape: (1, 32, 32, 3)
# 22107.png
# Input image shape: (1, 32, 32, 3)
# 22108.png
# Input image shape: (1, 32, 32, 3)
# 22109.png
# Input image shape: (1, 32, 32, 3)
# 22110.png
# Input image shape: (1, 32, 32, 3)
# 22111.png
# Input image shape: (1, 32, 32, 3)
# 22112.png
# Input image shape: (1, 32, 32, 3)
# 22113.png
# Input image shape: (1, 32, 32, 3)
# 22114.png
# Input image shape: (1, 32, 32, 3)
# 22115.png
# Input image shape: (1, 32, 32, 3)
# 22116.png
# Input image shape: (1, 32, 32, 3)
# 22117.png
# Input image shape: (1, 32, 32, 3)
# 22118.png
# Input image shape: (1, 32, 32, 3)
# 22119.png
# Input image shape: (1, 32, 32, 3)
# 22120.png
# Input image shape: (1, 32, 32, 3)
# 22121.png
# Input image shape: (1, 32, 32, 3)
# 22122.png
# Input image shape: (1, 32, 32, 3)
# 22123.png
# Input image shape: (1, 32, 32, 3)
# 22124.png
# Input image shape: (1, 32, 32, 3)
# 22125.png
# Input image shape: (1, 32, 32, 3)
# 22126.png
# Input image shape: (1, 32, 32, 3)
# 22127.png
# Input image shape: (1, 32, 32, 3)
# 22128.png
# Input image shape: (1, 32, 32, 3)
# 22129.png
# Input image shape: (1, 32, 32, 3)
# 22130.png
# Input image shape: (1, 32, 32, 3)
# 22131.png
# Input image shape: (1, 32, 32, 3)
# 22132.png
# Input image shape: (1, 32, 32, 3)
# 22133.png
# Input image shape: (1, 32, 32, 3)
# 22134.png
# Input image shape: (1, 32, 32, 3)
# 22135.png
# Input image shape: (1, 32, 32, 3)
# 22136.png
# Input image shape: (1, 32, 32, 3)
# 22137.png
# Input image shape: (1, 32, 32, 3)
# 22138.png
# Input image shape: (1, 32, 32, 3)
# 22139.png
# Input image shape: (1, 32, 32, 3)
# 22140.png
# Input image shape: (1, 32, 32, 3)
# 22143.png
# Input image shape: (1, 32, 32, 3)
# 22144.png
# Input image shape: (1, 32, 32, 3)
# 22146.png
# Input image shape: (1, 32, 32, 3)
# 22147.png
# Input image shape: (1, 32, 32, 3)
# 22148.png
# Input image shape: (1, 32, 32, 3)
# 22149.png
# Input image shape: (1, 32, 32, 3)
# 22150.png
# Input image shape: (1, 32, 32, 3)
# 22151.png
# Input image shape: (1, 32, 32, 3)
# 22152.png
# Input image shape: (1, 32, 32, 3)
# 22153.png
# Input image shape: (1, 32, 32, 3)
# 22154.png
# Input image shape: (1, 32, 32, 3)
# 22155.png
# Input image shape: (1, 32, 32, 3)
# 22156.png
# Input image shape: (1, 32, 32, 3)
# 22157.png
# Input image shape: (1, 32, 32, 3)
# 22158.png
# Input image shape: (1, 32, 32, 3)
# 22159.png
# Input image shape: (1, 32, 32, 3)
# 22160.png
# Input image shape: (1, 32, 32, 3)
# 22161.png
# Input image shape: (1, 32, 32, 3)
# 22162.png
# Input image shape: (1, 32, 32, 3)
# 22163.png
# Input image shape: (1, 32, 32, 3)
# 22164.png
# Input image shape: (1, 32, 32, 3)
# 22166.png
# Input image shape: (1, 32, 32, 3)
# 22167.png
# Input image shape: (1, 32, 32, 3)
# 22168.png
# Input image shape: (1, 32, 32, 3)
# 22169.png
# Input image shape: (1, 32, 32, 3)
# 22170.png
# Input image shape: (1, 32, 32, 3)
# 22171.png
# Input image shape: (1, 32, 32, 3)
# 22172.png
# Input image shape: (1, 32, 32, 3)
# 22173.png
# Input image shape: (1, 32, 32, 3)
# 22174.png
# Input image shape: (1, 32, 32, 3)
# 22175.png
# Input image shape: (1, 32, 32, 3)
# 22176.png
# Input image shape: (1, 32, 32, 3)
# 22177.png
# Input image shape: (1, 32, 32, 3)
# 22178.png
# Input image shape: (1, 32, 32, 3)
# 22179.png
# Input image shape: (1, 32, 32, 3)
# 22180.png
# Input image shape: (1, 32, 32, 3)
# 22181.png
# Input image shape: (1, 32, 32, 3)
# 22182.png
# Input image shape: (1, 32, 32, 3)
# 22183.png
# Input image shape: (1, 32, 32, 3)
# 22185.png
# Input image shape: (1, 32, 32, 3)
# 22186.png
# Input image shape: (1, 32, 32, 3)
# 22187.png
# Input image shape: (1, 32, 32, 3)
# 22188.png
# Input image shape: (1, 32, 32, 3)
# 22189.png
# Input image shape: (1, 32, 32, 3)
# 22190.png
# Input image shape: (1, 32, 32, 3)
# 22191.png
# Input image shape: (1, 32, 32, 3)
# 22192.png
# Input image shape: (1, 32, 32, 3)
# 22193.png
# Input image shape: (1, 32, 32, 3)
# 22194.png
# Input image shape: (1, 32, 32, 3)
# 22195.png
# Input image shape: (1, 32, 32, 3)
# 22196.png
# Input image shape: (1, 32, 32, 3)
# 22197.png
# Input image shape: (1, 32, 32, 3)
# 22198.png
# Input image shape: (1, 32, 32, 3)
# 22199.png
# Input image shape: (1, 32, 32, 3)
# 22200.png
# Input image shape: (1, 32, 32, 3)
# 22201.png
# Input image shape: (1, 32, 32, 3)
# 22207.png
# Input image shape: (1, 32, 32, 3)
# 22208.png
# Input image shape: (1, 32, 32, 3)
# 22209.png
# Input image shape: (1, 32, 32, 3)
# 22210.png
# Input image shape: (1, 32, 32, 3)
# 22212.png
# Input image shape: (1, 32, 32, 3)
# 22213.png
# Input image shape: (1, 32, 32, 3)
# 22214.png
# Input image shape: (1, 32, 32, 3)
# 22215.png
# Input image shape: (1, 32, 32, 3)
# 22216.png
# Input image shape: (1, 32, 32, 3)
# 22218.png
# Input image shape: (1, 32, 32, 3)
# 22219.png
# Input image shape: (1, 32, 32, 3)
# 22220.png
# Input image shape: (1, 32, 32, 3)
# 22221.png
# Input image shape: (1, 32, 32, 3)
# 22222.png
# Input image shape: (1, 32, 32, 3)
# 22223.png
# Input image shape: (1, 32, 32, 3)
# 22224.png
# Input image shape: (1, 32, 32, 3)
# 22225.png
# Input image shape: (1, 32, 32, 3)
# 22226.png
# Input image shape: (1, 32, 32, 3)
# 22227.png
# Input image shape: (1, 32, 32, 3)
# 22228.png
# Input image shape: (1, 32, 32, 3)
# 22229.png
# Input image shape: (1, 32, 32, 3)
# 22230.png
# Input image shape: (1, 32, 32, 3)
# 22231.png
# Input image shape: (1, 32, 32, 3)
# 22232.png
# Input image shape: (1, 32, 32, 3)
# 22233.png
# Input image shape: (1, 32, 32, 3)
# 22234.png
# Input image shape: (1, 32, 32, 3)
# 22235.png
# Input image shape: (1, 32, 32, 3)
# 22237.png
# Input image shape: (1, 32, 32, 3)
# 22238.png
# Input image shape: (1, 32, 32, 3)
# 22239.png
# Input image shape: (1, 32, 32, 3)
# 22240.png
# Input image shape: (1, 32, 32, 3)
# 22241.png
# Input image shape: (1, 32, 32, 3)
# 22242.png
# Input image shape: (1, 32, 32, 3)
# 22243.png
# Input image shape: (1, 32, 32, 3)
# 22244.png
# Input image shape: (1, 32, 32, 3)
# 22245.png
# Input image shape: (1, 32, 32, 3)
# 22246.png
# Input image shape: (1, 32, 32, 3)
# 22247.png
# Input image shape: (1, 32, 32, 3)
# 22248.png
# Input image shape: (1, 32, 32, 3)
# 22250.png
# Input image shape: (1, 32, 32, 3)
# 22251.png
# Input image shape: (1, 32, 32, 3)
# 22252.png
# Input image shape: (1, 32, 32, 3)
# 22253.png
# Input image shape: (1, 32, 32, 3)
# 22254.png
# Input image shape: (1, 32, 32, 3)
# 22255.png
# Input image shape: (1, 32, 32, 3)
# 22256.png
# Input image shape: (1, 32, 32, 3)
# 22257.png
# Input image shape: (1, 32, 32, 3)
# 22258.png
# Input image shape: (1, 32, 32, 3)
# 22259.png
# Input image shape: (1, 32, 32, 3)
# 22260.png
# Input image shape: (1, 32, 32, 3)
# 22261.png
# Input image shape: (1, 32, 32, 3)
# 22262.png
# Input image shape: (1, 32, 32, 3)
# 22263.png
# Input image shape: (1, 32, 32, 3)
# 22264.png
# Input image shape: (1, 32, 32, 3)
# 22265.png
# Input image shape: (1, 32, 32, 3)
# 22266.png
# Input image shape: (1, 32, 32, 3)
# 22268.png
# Input image shape: (1, 32, 32, 3)
# 22269.png
# Input image shape: (1, 32, 32, 3)
# 22270.png
# Input image shape: (1, 32, 32, 3)
# 22271.png
# Input image shape: (1, 32, 32, 3)
# 22272.png
# Input image shape: (1, 32, 32, 3)
# 22273.png
# Input image shape: (1, 32, 32, 3)
# 22274.png
# Input image shape: (1, 32, 32, 3)
# 22275.png
# Input image shape: (1, 32, 32, 3)
# 22276.png
# Input image shape: (1, 32, 32, 3)
# 22277.png
# Input image shape: (1, 32, 32, 3)
# 22278.png
# Input image shape: (1, 32, 32, 3)
# 22280.png
# Input image shape: (1, 32, 32, 3)
# 22281.png
# Input image shape: (1, 32, 32, 3)
# 22282.png
# Input image shape: (1, 32, 32, 3)
# 22283.png
# Input image shape: (1, 32, 32, 3)
# 22284.png
# Input image shape: (1, 32, 32, 3)
# 22285.png
# Input image shape: (1, 32, 32, 3)
# 22286.png
# Input image shape: (1, 32, 32, 3)
# 22287.png
# Input image shape: (1, 32, 32, 3)
# 22288.png
# Input image shape: (1, 32, 32, 3)
# 22289.png
# Input image shape: (1, 32, 32, 3)
# 22290.png
# Input image shape: (1, 32, 32, 3)
# 22291.png
# Input image shape: (1, 32, 32, 3)
# 22292.png
# Input image shape: (1, 32, 32, 3)
# 22293.png
# Input image shape: (1, 32, 32, 3)
# 22294.png
# Input image shape: (1, 32, 32, 3)
# 22295.png
# Input image shape: (1, 32, 32, 3)
# 22296.png
# Input image shape: (1, 32, 32, 3)
# 22297.png
# Input image shape: (1, 32, 32, 3)
# 22298.png
# Input image shape: (1, 32, 32, 3)
# 22299.png
# Input image shape: (1, 32, 32, 3)
# 22300.png
# Input image shape: (1, 32, 32, 3)
# 22301.png
# Input image shape: (1, 32, 32, 3)
# 22302.png
# Input image shape: (1, 32, 32, 3)
# 22303.png
# Input image shape: (1, 32, 32, 3)
# 22304.png
# Input image shape: (1, 32, 32, 3)
# 22305.png
# Input image shape: (1, 32, 32, 3)
# 22306.png
# Input image shape: (1, 32, 32, 3)
# 22307.png
# Input image shape: (1, 32, 32, 3)
# 22308.png
# Input image shape: (1, 32, 32, 3)
# 22309.png
# Input image shape: (1, 32, 32, 3)
# 22310.png
# Input image shape: (1, 32, 32, 3)
# 22311.png
# Input image shape: (1, 32, 32, 3)
# 22312.png
# Input image shape: (1, 32, 32, 3)
# 22313.png
# Input image shape: (1, 32, 32, 3)
# 22314.png
# Input image shape: (1, 32, 32, 3)
# 22315.png
# Input image shape: (1, 32, 32, 3)
# 22316.png
# Input image shape: (1, 32, 32, 3)
# 22317.png
# Input image shape: (1, 32, 32, 3)
# 22318.png
# Input image shape: (1, 32, 32, 3)
# 22319.png
# Input image shape: (1, 32, 32, 3)
# 22320.png
# Input image shape: (1, 32, 32, 3)
# 22321.png
# Input image shape: (1, 32, 32, 3)
# 22322.png
# Input image shape: (1, 32, 32, 3)
# 22323.png
# Input image shape: (1, 32, 32, 3)
# 22324.png
# Input image shape: (1, 32, 32, 3)
# 22325.png
# Input image shape: (1, 32, 32, 3)
# 22326.png
# Input image shape: (1, 32, 32, 3)
# 22327.png
# Input image shape: (1, 32, 32, 3)
# 22328.png
# Input image shape: (1, 32, 32, 3)
# 22329.png
# Input image shape: (1, 32, 32, 3)
# 22330.png
# Input image shape: (1, 32, 32, 3)
# 22331.png
# Input image shape: (1, 32, 32, 3)
# 22332.png
# Input image shape: (1, 32, 32, 3)
# 22333.png
# Input image shape: (1, 32, 32, 3)
# 22334.png
# Input image shape: (1, 32, 32, 3)
# 22337.png
# Input image shape: (1, 32, 32, 3)
# 22338.png
# Input image shape: (1, 32, 32, 3)
# 22339.png
# Input image shape: (1, 32, 32, 3)
# 22340.png
# Input image shape: (1, 32, 32, 3)
# 22341.png
# Input image shape: (1, 32, 32, 3)
# 22342.png
# Input image shape: (1, 32, 32, 3)
# 22343.png
# Input image shape: (1, 32, 32, 3)
# 22344.png
# Input image shape: (1, 32, 32, 3)
# 22345.png
# Input image shape: (1, 32, 32, 3)
# 22346.png
# Input image shape: (1, 32, 32, 3)
# 22347.png
# Input image shape: (1, 32, 32, 3)
# 22348.png
# Input image shape: (1, 32, 32, 3)
# 22349.png
# Input image shape: (1, 32, 32, 3)
# 22350.png
# Input image shape: (1, 32, 32, 3)
# 22351.png
# Input image shape: (1, 32, 32, 3)
# 22352.png
# Input image shape: (1, 32, 32, 3)
# 22353.png
# Input image shape: (1, 32, 32, 3)
# 22354.png
# Input image shape: (1, 32, 32, 3)
# 22355.png
# Input image shape: (1, 32, 32, 3)
# 22356.png
# Input image shape: (1, 32, 32, 3)
# 22357.png
# Input image shape: (1, 32, 32, 3)
# 22358.png
# Input image shape: (1, 32, 32, 3)
# 22359.png
# Input image shape: (1, 32, 32, 3)
# 22360.png
# Input image shape: (1, 32, 32, 3)
# 22361.png
# Input image shape: (1, 32, 32, 3)
# 22362.png
# Input image shape: (1, 32, 32, 3)
# 22363.png
# Input image shape: (1, 32, 32, 3)
# 22364.png
# Input image shape: (1, 32, 32, 3)
# 22365.png
# Input image shape: (1, 32, 32, 3)
# 22366.png
# Input image shape: (1, 32, 32, 3)
# 22367.png
# Input image shape: (1, 32, 32, 3)
# 22368.png
# Input image shape: (1, 32, 32, 3)
# 22369.png
# Input image shape: (1, 32, 32, 3)
# 22370.png
# Input image shape: (1, 32, 32, 3)
# 22371.png
# Input image shape: (1, 32, 32, 3)
# 22372.png
# Input image shape: (1, 32, 32, 3)
# 22373.png
# Input image shape: (1, 32, 32, 3)
# 22374.png
# Input image shape: (1, 32, 32, 3)
# 22376.png
# Input image shape: (1, 32, 32, 3)
# 22377.png
# Input image shape: (1, 32, 32, 3)
# 22379.png
# Input image shape: (1, 32, 32, 3)
# 22380.png
# Input image shape: (1, 32, 32, 3)
# 22381.png
# Input image shape: (1, 32, 32, 3)
# 22382.png
# Input image shape: (1, 32, 32, 3)
# 22383.png
# Input image shape: (1, 32, 32, 3)
# 22384.png
# Input image shape: (1, 32, 32, 3)
# 22385.png
# Input image shape: (1, 32, 32, 3)
# 22386.png
# Input image shape: (1, 32, 32, 3)
# 22387.png
# Input image shape: (1, 32, 32, 3)
# 22388.png
# Input image shape: (1, 32, 32, 3)
# 22389.png
# Input image shape: (1, 32, 32, 3)
# 22390.png
# Input image shape: (1, 32, 32, 3)
# 22391.png
# Input image shape: (1, 32, 32, 3)
# 22392.png
# Input image shape: (1, 32, 32, 3)
# 22393.png
# Input image shape: (1, 32, 32, 3)
# 22394.png
# Input image shape: (1, 32, 32, 3)
# 22395.png
# Input image shape: (1, 32, 32, 3)
# 22396.png
# Input image shape: (1, 32, 32, 3)
# 22397.png
# Input image shape: (1, 32, 32, 3)
# 22398.png
# Input image shape: (1, 32, 32, 3)
# 22399.png
# Input image shape: (1, 32, 32, 3)
# 22400.png
# Input image shape: (1, 32, 32, 3)
# 22401.png
# Input image shape: (1, 32, 32, 3)
# 22402.png
# Input image shape: (1, 32, 32, 3)
# 22403.png
# Input image shape: (1, 32, 32, 3)
# 22404.png
# Input image shape: (1, 32, 32, 3)
# 22405.png
# Input image shape: (1, 32, 32, 3)
# 22406.png
# Input image shape: (1, 32, 32, 3)
# 22407.png
# Input image shape: (1, 32, 32, 3)
# 22408.png
# Input image shape: (1, 32, 32, 3)
# 22409.png
# Input image shape: (1, 32, 32, 3)
# 22410.png
# Input image shape: (1, 32, 32, 3)
# 22411.png
# Input image shape: (1, 32, 32, 3)
# 22412.png
# Input image shape: (1, 32, 32, 3)
# 22413.png
# Input image shape: (1, 32, 32, 3)
# 22414.png
# Input image shape: (1, 32, 32, 3)
# 22415.png
# Input image shape: (1, 32, 32, 3)
# 22417.png
# Input image shape: (1, 32, 32, 3)
# 22418.png
# Input image shape: (1, 32, 32, 3)
# 22419.png
# Input image shape: (1, 32, 32, 3)
# 22420.png
# Input image shape: (1, 32, 32, 3)
# 22421.png
# Input image shape: (1, 32, 32, 3)
# 22422.png
# Input image shape: (1, 32, 32, 3)
# 22423.png
# Input image shape: (1, 32, 32, 3)
# 22424.png
# Input image shape: (1, 32, 32, 3)
# 22425.png
# Input image shape: (1, 32, 32, 3)
# 22426.png
# Input image shape: (1, 32, 32, 3)
# 22427.png
# Input image shape: (1, 32, 32, 3)
# 22428.png
# Input image shape: (1, 32, 32, 3)
# 22429.png
# Input image shape: (1, 32, 32, 3)
# 22430.png
# Input image shape: (1, 32, 32, 3)
# 22431.png
# Input image shape: (1, 32, 32, 3)
# 22432.png
# Input image shape: (1, 32, 32, 3)
# 22433.png
# Input image shape: (1, 32, 32, 3)
# 22434.png
# Input image shape: (1, 32, 32, 3)
# 22435.png
# Input image shape: (1, 32, 32, 3)
# 22437.png
# Input image shape: (1, 32, 32, 3)
# 22438.png
# Input image shape: (1, 32, 32, 3)
# 22439.png
# Input image shape: (1, 32, 32, 3)
# 22442.png
# Input image shape: (1, 32, 32, 3)
# 22443.png
# Input image shape: (1, 32, 32, 3)
# 22444.png
# Input image shape: (1, 32, 32, 3)
# (20280, 1, 32, 32, 3)
# (1, 20280, 32, 32, 3)
# (20280, 32, 32, 3)
# sample 20280
# Epoch 1/2
#  - 774s - loss: 32.3170 - accuracy: 0.3405 - val_loss: 1012.8167 - val_accuracy: 0.3868
# Epoch 2/2
#  - 751s - loss: 27.2228 - accuracy: 0.3613 - val_loss: 23.7763 - val_accuracy: 0.4014
# Max Test accuracy: 0.40138065814971924
# 4056/4056 [==============================] - 67s 16ms/step
# Test loss: 23.776321990485258
# Test accuracy: 0.40138065814971924
# ---  Training time in seconds ---1621675787.478841
# D:\Anaconda\lib\site-packages\ipykernel_launcher.py:290: DeprecationWarning: elementwise comparison failed; this will raise an error in the future.
